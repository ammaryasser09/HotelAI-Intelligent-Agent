# %%
import pandas as pd

# %%
faq_data = [

    # =========================
    # CHECK-IN / CHECK-OUT
    # =========================

    {
        "faq_id": "FAQ001",
        "category": "Check-in",
        "question": "What time is check-in?",
        "answer": "Check-in starts at 3:00 PM.",
        "language": "English"
    },
    {
        "faq_id": "FAQ002",
        "category": "Check-out",
        "question": "What time is check-out?",
        "answer": "Check-out is at 12:00 PM.",
        "language": "English"
    },
    {
        "faq_id": "FAQ003",
        "category": "Check-in",
        "question": "Can I check in early?",
        "answer": "Early check-in is subject to room availability and hotel approval.",
        "language": "English"
    },
    {
        "faq_id": "FAQ004",
        "category": "Check-out",
        "question": "Can I check out late?",
        "answer": "Late checkout is subject to availability and may have an additional fee.",
        "language": "English"
    },

    # =========================
    # BOOKING
    # =========================

    {
        "faq_id": "FAQ005",
        "category": "Booking",
        "question": "How can I make a reservation?",
        "answer": "Guests can make a reservation through the hotel website, phone, booking platforms, or customer service agent.",
        "language": "English"
    },
    {
        "faq_id": "FAQ006",
        "category": "Booking",
        "question": "Can I modify my reservation?",
        "answer": "Yes, reservation modifications may be requested through customer service and are subject to availability.",
        "language": "English"
    },
    {
        "faq_id": "FAQ007",
        "category": "Booking",
        "question": "Can I cancel my reservation?",
        "answer": "Standard reservations can be cancelled free of charge up to 48 hours before check-in.",
        "language": "English"
    },

    # =========================
    # PAYMENTS
    # =========================

    {
        "faq_id": "FAQ008",
        "category": "Payment",
        "question": "What payment methods do you accept?",
        "answer": "The hotel accepts credit cards, debit cards, cash, bank transfers, and digital wallets.",
        "language": "English"
    },
    {
        "faq_id": "FAQ009",
        "category": "Payment",
        "question": "How long does a refund take?",
        "answer": "Approved refunds are normally processed within 5 to 10 business days.",
        "language": "English"
    },
    {
        "faq_id": "FAQ010",
        "category": "Payment",
        "question": "What happens if my payment fails?",
        "answer": "Guests can retry the payment using another supported payment method.",
        "language": "English"
    },

    # =========================
    # SERVICES
    # =========================

    {
        "faq_id": "FAQ011",
        "category": "Services",
        "question": "Is room service available?",
        "answer": "Yes, room service is available 24 hours a day.",
        "language": "English"
    },
    {
        "faq_id": "FAQ012",
        "category": "Services",
        "question": "Do you provide airport transfer?",
        "answer": "Yes, airport transfer is available upon request for 800 EGP per trip.",
        "language": "English"
    },
    {
        "faq_id": "FAQ013",
        "category": "Services",
        "question": "Is laundry service available?",
        "answer": "Yes, laundry and dry-cleaning services are available daily.",
        "language": "English"
    },
    {
        "faq_id": "FAQ014",
        "category": "Services",
        "question": "Can I request an extra bed?",
        "answer": "Yes, an extra bed can be requested depending on room capacity and availability.",
        "language": "English"
    },

    # =========================
    # FACILITIES
    # =========================

    {
        "faq_id": "FAQ015",
        "category": "Facilities",
        "question": "Does the hotel have a swimming pool?",
        "answer": "Yes, the swimming pool is available from 7:00 AM to 9:00 PM.",
        "language": "English"
    },
    {
        "faq_id": "FAQ016",
        "category": "Facilities",
        "question": "Is the gym open 24 hours?",
        "answer": "Yes, the gym is open 24/7 for hotel guests.",
        "language": "English"
    },
    {
        "faq_id": "FAQ017",
        "category": "Facilities",
        "question": "Is Wi-Fi free?",
        "answer": "Yes, free Wi-Fi is available in all rooms and public areas.",
        "language": "English"
    },
    {
        "faq_id": "FAQ018",
        "category": "Facilities",
        "question": "Does the hotel have parking?",
        "answer": "Yes, parking is available for hotel guests.",
        "language": "English"
    },

    # =========================
    # POLICIES
    # =========================

    {
        "faq_id": "FAQ019",
        "category": "Policies",
        "question": "Are pets allowed?",
        "answer": "No, pets are not allowed inside the hotel.",
        "language": "English"
    },
    {
        "faq_id": "FAQ020",
        "category": "Policies",
        "question": "Is smoking allowed inside rooms?",
        "answer": "No, smoking is not permitted inside guest rooms or indoor public areas.",
        "language": "English"
    },

    # =========================
    # ROOMS
    # =========================

    {
        "faq_id": "FAQ021",
        "category": "Rooms",
        "question": "How many guests can stay in a suite?",
        "answer": "A suite can accommodate up to 4 guests.",
        "language": "English"
    },
    {
        "faq_id": "FAQ022",
        "category": "Rooms",
        "question": "What amenities are available in the rooms?",
        "answer": "Rooms include free Wi-Fi, air conditioning, a private bathroom, television, housekeeping, toiletries, and towels.",
        "language": "English"
    }
]

# %%
faq_df = pd.DataFrame(faq_data)

faq_df.head()
# Out:
#    faq_id   category                       question  \
# 0  FAQ001   Check-in         What time is check-in?
# 1  FAQ002  Check-out        What time is check-out?
# 2  FAQ003   Check-in          Can I check in early?
# 3  FAQ004  Check-out          Can I check out late?
# 4  FAQ005    Booking  How can I make a reservation?
#
#                                               answer language
# 0                        Check-in starts at 3:00 PM.  English
# 1                          Check-out is at 12:00 PM.  English
# 2  Early check-in is subject to room availability...  English
# 3  Late checkout is subject to availability and m...  English
# 4  Guests can make a reservation through the hote...  English

# %%
print("Number of FAQs:", len(faq_df))
# Out:
# Number of FAQs: 22

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\User\OneDrive\سطح المكتب\HotelAI

# %%
import os

output_dir = "03_Structured_Data/CSV"

os.makedirs(output_dir, exist_ok=True)

faq_df.to_csv(
    os.path.join(output_dir, "hotel_faq.csv"),
    index=False,
    encoding="utf-8-sig"
)

print("Saved successfully!")
# Out:
# Saved successfully!

# %%
languages = [
    "English",
    "Arabic",
    "French",
    "Russian"
]

print(languages)
# Out:
# ['English', 'Arabic', 'French', 'Russian']

# %%
categories = [
    "Hotel Information",
    "Rooms",
    "Booking",
    "Cancellation",
    "Check-in and Check-out",
    "Restaurant",
    "Breakfast",
    "Facilities",
    "Wi-Fi",
    "Parking",
    "Transportation",
    "Room Service",
    "Housekeeping",
    "Payment",
    "Policies",
    "Complaints"
]

print(categories)
# Out:
# ['Hotel Information', 'Rooms', 'Booking', 'Cancellation', 'Check-in and Check-out', 'Restaurant', 'Breakfast', 'Facilities', 'Wi-Fi', 'Parking', 'Transportation', 'Room Service', 'Housekeeping', 'Payment', 'Policies', 'Complaints']

# %%
columns = [
    "language",
    "category",
    "question",
    "answer",
    "source"
]

print(columns)
# Out:
# ['language', 'category', 'question', 'answer', 'source']

# %%
import pandas as pd

faq_df = pd.DataFrame(columns=columns)

print(faq_df.head())
# Out:
# Empty DataFrame
# Columns: [language, category, question, answer, source]
# Index: []

# %%
prompt_template = """
You are generating a multilingual FAQ dataset for a hotel AI assistant.

Hotel information:
{hotel_information}

Category:
{category}

Generate one high-quality FAQ pair.

Language:
{language}

Requirements:
- The question must be natural and realistic.
- The answer must be accurate and based ONLY on the provided hotel information.
- Do not invent hotel policies, prices, services, or facilities.
- Do not add information that is not present in the source.
- Keep the answer clear and concise.
- Return only the question and answer.

Format:

Question: ...
Answer: ...
"""

print(prompt_template)
# Out:
# You are generating a multilingual FAQ dataset for a hotel AI assistant.
#
# Hotel information:
# {hotel_information}
#
# Category:
# {category}
#
# Generate one high-quality FAQ pair.
#
# Language:
# {language}
#
# Requirements:
# - The question must be natural and realistic.
# - The answer must be accurate and based ONLY on the provided hotel information.
# - Do not invent hotel policies, prices, services, or facilities.
# - Do not add information that is not present in the source.
# - Keep the answer clear and concise.
# - Return only the question and answer.
#
# Format:
#
# Question: ...
# Answer: ...

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\User\OneDrive\سطح المكتب\HotelAI
# ['02_Hotel_Knowledge', '03_Structured_Data', 'data', 'database', 'generate_hotel_faq.ipynb', 'README.md', 'scripts']

# %%
knowledge_path = "02_Hotel_Knowledge"

print(os.listdir(knowledge_path))
# Out:
# ['DOCX', 'PDF', 'TXT']

# %%
import os

for folder in ["DOCX", "PDF", "TXT"]:
    folder_path = os.path.join("02_Hotel_Knowledge", folder)
    
    print(f"\n--- {folder} ---")
    
    files = os.listdir(folder_path)
    
    for file in files:
        print(file)
# Out:
# --- DOCX ---
# hotel_services.docx
# room_information.docx
#
# --- PDF ---
# cancellation_policy.pdf
# hotel_policies.pdf
# payment_refund_policy.pdf
#
# --- TXT ---
# faq.txt
# hotel_information.txt

# %%
import os
from docx import Document
from pypdf import PdfReader

# %%
def read_txt(file_path):
    with open(file_path, "r", encoding="utf-8") as file:
        return file.read()


def read_docx(file_path):
    document = Document(file_path)
    return "\n".join(
        paragraph.text
        for paragraph in document.paragraphs
        if paragraph.text.strip()
    )


def read_pdf(file_path):
    reader = PdfReader(file_path)
    
    text = []
    
    for page in reader.pages:
        page_text = page.extract_text()
        
        if page_text:
            text.append(page_text)
    
    return "\n".join(text)

# %%
knowledge_path = "02_Hotel_Knowledge"

hotel_knowledge = []

for folder in ["TXT", "DOCX", "PDF"]:
    
    folder_path = os.path.join(knowledge_path, folder)
    
    for file_name in os.listdir(folder_path):
        
        file_path = os.path.join(folder_path, file_name)
        
        if folder == "TXT":
            content = read_txt(file_path)
            
        elif folder == "DOCX":
            content = read_docx(file_path)
            
        elif folder == "PDF":
            content = read_pdf(file_path)
        
        hotel_knowledge.append({
            "source": file_name,
            "content": content
        })

print(f"Loaded {len(hotel_knowledge)} documents")
# Out:
# ---------------------------------------------------------------------------
# PackageNotFoundError                      Traceback (most recent call last)
# Cell In[20], line 17
#      14     content = read_txt(file_path)
#      16 elif folder == "DOCX":
# ---> 17     content = read_docx(file_path)
#      19 elif folder == "PDF":
#      20     content = read_pdf(file_path)
#
# Cell In[19], line 7, in read_docx(file_path)
#       6 def read_docx(file_path):
# ----> 7     document = Document(file_path)
#       8     return "\n".join(
#       9         paragraph.text
#      10         for paragraph in document.paragraphs
#      11         if paragraph.text.strip()
#      12     )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\docx\api.py:27, in Document(docx)
#      20 """Return a |Document| object loaded from `docx`, where `docx` can be either a path
#      21 to a ``.docx`` file (a string) or a file-like object.
#      22
# ...

# %%
import os

docx_path = "02_Hotel_Knowledge/DOCX"

for file_name in os.listdir(docx_path):
    file_path = os.path.join(docx_path, file_name)
    
    print(f"File: {file_name}")
    print(f"Exists: {os.path.exists(file_path)}")
    print(f"Size: {os.path.getsize(file_path)} bytes")
    print("-" * 40)
# Out:
# File: hotel_services.docx
# Exists: True
# Size: 1776 bytes
# ----------------------------------------
# File: room_information.docx
# Exists: True
# Size: 2073 bytes
# ----------------------------------------

# %%
import zipfile

for file_name in ["hotel_services.docx", "room_information.docx"]:
    
    file_path = os.path.join(
        "02_Hotel_Knowledge",
        "DOCX",
        file_name
    )
    
    print(f"\n{file_name}")
    print("Is valid DOCX:", zipfile.is_zipfile(file_path))
# Out:
# hotel_services.docx
# Is valid DOCX: False
#
# room_information.docx
# Is valid DOCX: False

# %%
for file_name in ["hotel_services.docx", "room_information.docx"]:
    
    file_path = os.path.join(
        "02_Hotel_Knowledge",
        "DOCX",
        file_name
    )
    
    print("\n" + "=" * 60)
    print(file_name)
    print("=" * 60)
    
    with open(file_path, "rb") as file:
        content = file.read()
    
    print(content[:1000])
# Out:
# ...
# hotel_services.docx
# ...

# %%
def read_docx(file_path):
    try:
        document = Document(file_path)
        
        return "\n".join(
            paragraph.text
            for paragraph in document.paragraphs
            if paragraph.text.strip()
        )
    
    except Exception:
        with open(file_path, "r", encoding="utf-8") as file:
            return file.read()

# %%
def read_pdf(file_path):
    try:
        reader = PdfReader(file_path)

        text = []

        for page in reader.pages:
            page_text = page.extract_text()

            if page_text:
                text.append(page_text)

        return "\n".join(text)

    except Exception:
        with open(file_path, "r", encoding="utf-8") as file:
            return file.read()

# %%
def read_docx(file_path):
    try:
        document = Document(file_path)

        return "\n".join(
            paragraph.text
            for paragraph in document.paragraphs
            if paragraph.text.strip()
        )

    except Exception:
        with open(file_path, "r", encoding="utf-8") as file:
            return file.read()

# %%
knowledge_path = "02_Hotel_Knowledge"

hotel_knowledge = []

for folder in ["TXT", "DOCX", "PDF"]:

    folder_path = os.path.join(knowledge_path, folder)

    for file_name in os.listdir(folder_path):

        file_path = os.path.join(folder_path, file_name)

        if folder == "TXT":
            content = read_txt(file_path)

        elif folder == "DOCX":
            content = read_docx(file_path)

        elif folder == "PDF":
            content = read_pdf(file_path)

        hotel_knowledge.append({
            "source": file_name,
            "content": content
        })

print(f"Loaded {len(hotel_knowledge)} documents")
# Out:
# invalid pdf header: b'NILE '
# EOF marker not found
# invalid pdf header: b'NILE '
# EOF marker not found
# invalid pdf header: b'NILE '
# EOF marker not found
# Loaded 7 documents

# %%
print("Files in Knowledge Base:")

for folder in ["TXT", "DOCX", "PDF"]:
    
    folder_path = os.path.join("02_Hotel_Knowledge", folder)
    
    print(f"\n--- {folder} ---")
    
    for file_name in os.listdir(folder_path):
        print(file_name)
# Out:
# Files in Knowledge Base:
#
# --- TXT ---
# faq.txt
# hotel_information.txt
#
# --- DOCX ---
# hotel_services.docx
# room_information.docx
#
# --- PDF ---
# cancellation_policy.pdf
# hotel_policies.pdf
# payment_refund_policy.pdf

# %%
for document in hotel_knowledge:
    print(
        f"{document['source']} → "
        f"{len(document['content'])} characters"
    )
# Out:
# faq.txt → 952 characters
# hotel_information.txt → 525 characters
# hotel_services.docx → 1700 characters
# room_information.docx → 1999 characters
# cancellation_policy.pdf → 1088 characters
# hotel_policies.pdf → 1624 characters
# payment_refund_policy.pdf → 1302 characters

# %%
knowledge_text = ""

for document in hotel_knowledge:
    knowledge_text += (
        f"\n\n===== SOURCE: {document['source']} =====\n\n"
        f"{document['content']}"
    )

print(knowledge_text[:3000])
# Out:
# ===== SOURCE: faq.txt =====
#
# HOTEL FAQ
#
# Q: What time is check-in?
# A: Check-in starts at 3:00 PM.
#
# Q: What time is check-out?
# A: Check-out is at 12:00 PM.
#
# Q: Is the reception open 24 hours?
# A: Yes, the hotel reception is available 24/7.
#
# Q: Is breakfast available?
# A: Yes, breakfast is available daily from 7:00 AM to 10:30 AM.
#
# Q: Is Wi-Fi free?
# A: Yes, free Wi-Fi is available in all rooms and public areas.
#
# Q: Does the hotel have parking?
# A: Yes, parking is available for hotel guests.
#
# Q: Does the hotel have a swimming pool?
# A: Yes, the swimming pool is available from 7:00 AM to 9:00 PM.
#
# Q: Is the gym available 24 hours?
# A: Yes, the gym is open 24/7.
#
# Q: Does the hotel provide airport transfer?
# A: Yes, airport transfer is available upon request.
#
# Q: Is room service available?
# A: Yes, room service is available 24/7.
#
# Q: Are pets allowed?
# A: No, pets are not allowed.
#
# Q: What languages does the hotel support?
# ...

# %%
print("Total characters:", len(knowledge_text))
# Out:
# Total characters: 9492

# %%
columns = [
    "faq_id",
    "category",
    "question",
    "answer",
    "language"
]

faq_df = pd.DataFrame(columns=columns)

print(faq_df)
# Out:
# Empty DataFrame
# Columns: [faq_id, category, question, answer, language]
# Index: []

# %%
faq_id = "FAQ001"
category = "Check-in"

print(faq_id)
print(category)
# Out:
# FAQ001
# Check-in

# %%
checkin_knowledge = ""

for document in hotel_knowledge:
    if document["source"] in ["hotel_information.txt", "hotel_policies.pdf"]:
        checkin_knowledge += "\n" + document["content"]

print(checkin_knowledge)
# Out:
# HOTEL INFORMATION
#
# Hotel Name:
# Nile Pearl Hotel
#
# Location:
# Cairo, Egypt
#
# Hotel Category:
# 5-Star Hotel
#
# Check-in:
# 3:00 PM
#
# Check-out:
# 12:00 PM
#
# Reception:
# 24/7
#
# Breakfast:
# 7:00 AM - 10:30 AM
#
# Free Wi-Fi:
# Available in all rooms and public areas.
#
# Parking:
# Available for hotel guests.
#
# Swimming Pool:
# Available from 7:00 AM to 9:00 PM.
#
# Gym:
# Open 24/7 for hotel guests.
#
# Airport Transfer:
# Available upon request.
#
# Room Service:
# Available 24/7.
#
# Pets:
# Pets are not allowed.
#
# Languages Supported:
# Arabic, English, French, Russian.
# NILE PEARL HOTEL
# GENERAL HOTEL POLICIES
#
# 1. Check-in Policy
#
# Standard check-in time is 3:00 PM.
#
# Guests must provide valid identification during check-in.
#
# Early check-in is subject to room availability and hotel approval.
#
# 2. Check-out Policy
#
# Standard check-out time is 12:00 PM.
#
# Late checkout is subject to availability and may incur an additional fee.
#
# ...

# %%
faq_rows = [
    {
        "faq_id": "FAQ001",
        "category": "Check-in",
        "question": "What time is check-in?",
        "answer": "Standard check-in time is 3:00 PM.",
        "language": "English"
    },
    {
        "faq_id": "FAQ001",
        "category": "Check-in",
        "question": "متى يبدأ تسجيل الوصول؟",
        "answer": "يبدأ تسجيل الوصول في الساعة 3:00 مساءً.",
        "language": "Arabic"
    },
    {
        "faq_id": "FAQ001",
        "category": "Check-in",
        "question": "À quelle heure commence l'enregistrement ?",
        "answer": "L'enregistrement standard commence à 15h00.",
        "language": "French"
    },
    {
        "faq_id": "FAQ001",
        "category": "Check-in",
        "question": "Во сколько начинается регистрация?",
        "answer": "Стандартная регистрация начинается в 15:00.",
        "language": "Russian"
    }
]

faq_df = pd.DataFrame(faq_rows)

print(faq_df)
# Out:
#    faq_id  category                                    question  \
# 0  FAQ001  Check-in                      What time is check-in?
# 1  FAQ001  Check-in                      متى يبدأ تسجيل الوصول؟
# 2  FAQ001  Check-in  À quelle heure commence l'enregistrement ?
# 3  FAQ001  Check-in          Во сколько начинается регистрация?
#
#                                         answer language
# 0           Standard check-in time is 3:00 PM.  English
# 1      يبدأ تسجيل الوصول في الساعة 3:00 مساءً.   Arabic
# 2  L'enregistrement standard commence à 15h00.   French
# 3  Стандартная регистрация начинается в 15:00.  Russian

# %%
faqs_per_category = 5

print("FAQs per category:", faqs_per_category)
print("Languages:", len(languages))
print("Categories:", len(categories))

total_rows = (
    faqs_per_category
    * len(categories)
    * len(languages)
)

print("Expected total rows:", total_rows)
# Out:
# FAQs per category: 5
# Languages: 4
# Categories: 16
# Expected total rows: 320

# %%
category_sources = {
    "Hotel Information": [
        "hotel_information.txt"
    ],
    
    "Rooms": [
        "room_information.docx"
    ],
    
    "Booking": [
        "faq.txt"
    ],
    
    "Cancellation": [
        "cancellation_policy.pdf"
    ],
    
    "Check-in and Check-out": [
        "hotel_information.txt",
        "hotel_policies.pdf"
    ],
    
    "Breakfast": [
        "hotel_services.docx"
    ],
    
    "Restaurant": [
        "hotel_services.docx"
    ],
    
    "Facilities": [
        "hotel_information.txt",
        "hotel_services.docx"
    ],
    
    "Wi-Fi": [
        "hotel_information.txt"
    ],
    
    "Parking": [
        "hotel_information.txt"
    ],
    
    "Transportation": [
        "hotel_services.docx",
        "hotel_information.txt"
    ],
    
    "Room Service": [
        "hotel_services.docx"
    ],
    
    "Housekeeping": [
        "hotel_services.docx"
    ],
    
    "Payment": [
        "payment_refund_policy.pdf"
    ],
    
    "Hotel Policies": [
        "hotel_policies.pdf"
    ],
    
    "Complaints": [
        "faq.txt"
    ]
}

print(category_sources)
# Out:
# {'Hotel Information': ['hotel_information.txt'], 'Rooms': ['room_information.docx'], 'Booking': ['faq.txt'], 'Cancellation': ['cancellation_policy.pdf'], 'Check-in and Check-out': ['hotel_information.txt', 'hotel_policies.pdf'], 'Breakfast': ['hotel_services.docx'], 'Restaurant': ['hotel_services.docx'], 'Facilities': ['hotel_information.txt', 'hotel_services.docx'], 'Wi-Fi': ['hotel_information.txt'], 'Parking': ['hotel_information.txt'], 'Transportation': ['hotel_services.docx', 'hotel_information.txt'], 'Room Service': ['hotel_services.docx'], 'Housekeeping': ['hotel_services.docx'], 'Payment': ['payment_refund_policy.pdf'], 'Hotel Policies': ['hotel_policies.pdf'], 'Complaints': ['faq.txt']}

# %%
for category, sources in category_sources.items():
    print(f"{category}: {sources}")
# Out:
# Hotel Information: ['hotel_information.txt']
# Rooms: ['room_information.docx']
# Booking: ['faq.txt']
# Cancellation: ['cancellation_policy.pdf']
# Check-in and Check-out: ['hotel_information.txt', 'hotel_policies.pdf']
# Breakfast: ['hotel_services.docx']
# Restaurant: ['hotel_services.docx']
# Facilities: ['hotel_information.txt', 'hotel_services.docx']
# Wi-Fi: ['hotel_information.txt']
# Parking: ['hotel_information.txt']
# Transportation: ['hotel_services.docx', 'hotel_information.txt']
# Room Service: ['hotel_services.docx']
# Housekeeping: ['hotel_services.docx']
# Payment: ['payment_refund_policy.pdf']
# Hotel Policies: ['hotel_policies.pdf']
# Complaints: ['faq.txt']

# %%
def get_category_knowledge(category):
    sources = category_sources[category]
    
    knowledge = []
    
    for document in hotel_knowledge:
        if document["source"] in sources:
            knowledge.append(
                f"Source: {document['source']}\n"
                f"{document['content']}"
            )
    
    return "\n\n".join(knowledge)


checkin_knowledge = get_category_knowledge(
    "Check-in and Check-out"
)

print(checkin_knowledge)
# Out:
# Source: hotel_information.txt
# HOTEL INFORMATION
#
# Hotel Name:
# Nile Pearl Hotel
#
# Location:
# Cairo, Egypt
#
# Hotel Category:
# 5-Star Hotel
#
# Check-in:
# 3:00 PM
#
# Check-out:
# 12:00 PM
#
# Reception:
# 24/7
#
# Breakfast:
# 7:00 AM - 10:30 AM
#
# Free Wi-Fi:
# Available in all rooms and public areas.
#
# Parking:
# Available for hotel guests.
#
# Swimming Pool:
# Available from 7:00 AM to 9:00 PM.
#
# Gym:
# Open 24/7 for hotel guests.
#
# Airport Transfer:
# Available upon request.
#
# Room Service:
# Available 24/7.
#
# Pets:
# Pets are not allowed.
#
# Languages Supported:
# Arabic, English, French, Russian.
#
# Source: hotel_policies.pdf
# NILE PEARL HOTEL
# GENERAL HOTEL POLICIES
#
# 1. Check-in Policy
#
# Standard check-in time is 3:00 PM.
#
# Guests must provide valid identification during check-in.
#
# Early check-in is subject to room availability and hotel approval.
#
# 2. Check-out Policy
#
# Standard check-out time is 12:00 PM.
#
# ...

# %%
import os

ROOT = os.getcwd()

print("=" * 70)
print("HOTEL AI - PROJECT STRUCTURE")
print("=" * 70)

def print_tree(path, prefix=""):
    items = sorted(os.listdir(path))

    for i, item in enumerate(items):
        full_path = os.path.join(path, item)

        is_last = i == len(items) - 1
        connector = "└── " if is_last else "├── "

        print(prefix + connector + item)

        if os.path.isdir(full_path):
            extension = "    " if is_last else "│   "
            print_tree(full_path, prefix + extension)


print_tree(ROOT)
# Out:
# ...
# HOTEL AI - PROJECT STRUCTURE
# ...
# ├── 02_Hotel_Knowledge
# │   ├── DOCX
# │   │   ├── hotel_services.docx
# │   │   └── room_information.docx
# │   ├── PDF
# │   │   ├── cancellation_policy.pdf
# │   │   ├── hotel_policies.pdf
# │   │   └── payment_refund_policy.pdf
# │   └── TXT
# │       ├── faq.txt
# │       └── hotel_information.txt
# ├── 03_Structured_Data
# │   ├── CSV
# │   │   └── hotel_faq.csv
# │   ├── Excel
# │   └── JSON
# │       └── 03_Structured_Data
# │           └── JSON
# │               └── hotel_config.json
# ├── README.md
# ├── data
# │   ├── bookings.csv
# │   ├── customer_requests.csv
# │   ├── customers.csv
# │   ├── payments.csv
# │   ├── room_types.csv
# │   ├── rooms.csv
# │   └── services.csv
# ├── database
# │   └── hotel_ai_final_backup.backup
# ├── generate_hotel_faq.ipynb
# └── scripts
#     ├── generate_bookings.ipynb
#     ├── generate_customer_requests.ipynb
#     ├── generate_customers.ipynb
#     ├── generate_payments.ipynb
# ...

# %%
import os

knowledge_path = "02_Hotel_Knowledge"

folders = [
    "Hotel_Information",
    "Rooms",
    "Booking",
    "Services",
    "Policies",
    "Payment",
    "Cancellation"
]

for folder in folders:
    folder_path = os.path.join(knowledge_path, folder)
    os.makedirs(folder_path, exist_ok=True)

print("Hotel Knowledge structure created successfully.")

for folder in folders:
    print(f"✓ {folder}")
# Out:
# Hotel Knowledge structure created successfully.
# ✓ Hotel_Information
# ✓ Rooms
# ✓ Booking
# ✓ Services
# ✓ Policies
# ✓ Payment
# ✓ Cancellation

# %%
import os

knowledge_path = "02_Hotel_Knowledge"

print("=" * 70)
print("HOTEL KNOWLEDGE BASE - STRUCTURE CHECK")
print("=" * 70)

expected_structure = {
    "Hotel_Information": [
        "hotel_information.txt",
        "contact_information.txt",
        "hotel_facilities.txt"
    ],
    
    "Rooms": [
        "room_types.txt",
        "room_amenities.txt",
        "room_policies.txt"
    ],
    
    "Booking": [
        "booking_policy.txt",
        "booking_process.txt",
        "booking_modification.txt",
        "booking_confirmation.txt"
    ],
    
    "Payment": [
        "payment_methods.txt",
        "payment_policy.txt",
        "refund_policy.txt"
    ],
    
    "Cancellation": [
        "cancellation_policy.txt",
        "cancellation_process.txt"
    ],
    
    "Services": [],
    "Policies": []
}


all_correct = True

for folder, files in expected_structure.items():

    folder_path = os.path.join(
        knowledge_path,
        folder
    )

    print(f"\n📁 {folder}")

    if not os.path.exists(folder_path):
        print("   ❌ Folder does not exist")
        all_correct = False
        continue

    print("   ✅ Folder exists")

    for file_name in files:

        file_path = os.path.join(
            folder_path,
            file_name
        )

        if os.path.exists(file_path):
            size = os.path.getsize(file_path)

            if size > 0:
                print(f"   ✅ {file_name} ({size} bytes)")
            else:
                print(f"   ⚠️ {file_name} is EMPTY")
                all_correct = False

        else:
            print(f"   ❌ Missing: {file_name}")
            all_correct = False


print("\n" + "=" * 70)

if all_correct:
    print("✅ STRUCTURE CHECK PASSED")
else:
    print("⚠️ STRUCTURE NEEDS ATTENTION")
# Out:
# ...
# HOTEL KNOWLEDGE BASE - STRUCTURE CHECK
# ...
#
# 📁 Hotel_Information
#    ✅ Folder exists
#    ✅ hotel_information.txt (588 bytes)
#    ✅ contact_information.txt (776 bytes)
#    ✅ hotel_facilities.txt (1240 bytes)
#
# 📁 Rooms
#    ✅ Folder exists
#    ✅ room_types.txt (1213 bytes)
#    ✅ room_amenities.txt (964 bytes)
#    ✅ room_policies.txt (1130 bytes)
#
# 📁 Booking
#    ✅ Folder exists
#    ✅ booking_policy.txt (1706 bytes)
#    ✅ booking_process.txt (999 bytes)
#    ✅ booking_modification.txt (1453 bytes)
#    ✅ booking_confirmation.txt (1011 bytes)
#
# 📁 Payment
#    ✅ Folder exists
#    ✅ payment_methods.txt (894 bytes)
#    ✅ payment_policy.txt (1024 bytes)
#    ✅ refund_policy.txt (967 bytes)
#
# 📁 Cancellation
#    ✅ Folder exists
#    ✅ cancellation_policy.txt (1819 bytes)
#    ✅ cancellation_process.txt (1129 bytes)
#
# 📁 Services
#    ✅ Folder exists
#
# 📁 Policies
#    ✅ Folder exists
#
# ...
# ✅ STRUCTURE CHECK PASSED

# %%
import os

knowledge_path = "02_Hotel_Knowledge"

expected_structure = {
    "Hotel_Information": [
        "hotel_information.txt",
        "contact_information.txt",
        "hotel_facilities.txt"
    ],
    "Rooms": [
        "room_types.txt",
        "room_amenities.txt",
        "room_policies.txt"
    ],
    "Booking": [
        "booking_policy.txt",
        "booking_process.txt",
        "booking_modification.txt",
        "booking_confirmation.txt"
    ],
    "Payment": [
        "payment_methods.txt",
        "payment_policy.txt",
        "refund_policy.txt"
    ],
    "Cancellation": [
        "cancellation_policy.txt",
        "cancellation_process.txt"
    ],
    "Services": [],
    "Policies": []
}

missing = []
empty = []

for folder, files in expected_structure.items():

    folder_path = os.path.join(knowledge_path, folder)

    if not os.path.isdir(folder_path):
        missing.append(f"Folder: {folder}")
        continue

    for file_name in files:

        file_path = os.path.join(folder_path, file_name)

        if not os.path.isfile(file_path):
            missing.append(f"{folder}/{file_name}")

        elif os.path.getsize(file_path) == 0:
            empty.append(f"{folder}/{file_name}")


print("=" * 70)
print("FINAL KNOWLEDGE BASE CHECK")
print("=" * 70)

if not missing and not empty:
    print("✅ ALL REQUIRED FILES EXIST")
    print("✅ ALL FILES CONTAIN DATA")
    print("✅ STRUCTURE PASSED")
else:

    if missing:
        print("\n❌ MISSING:")
        for item in missing:
            print("   -", item)

    if empty:
        print("\n⚠️ EMPTY:")
        for item in empty:
            print("   -", item)

print("=" * 70)
# Out:
# ...
# FINAL KNOWLEDGE BASE CHECK
# ...
# ✅ ALL REQUIRED FILES EXIST
# ✅ ALL FILES CONTAIN DATA
# ✅ STRUCTURE PASSED
# ...

# %%
import os

services_path = os.path.join(
    "02_Hotel_Knowledge",
    "Services"
)

print("=" * 60)
print("SERVICES CHECK")
print("=" * 60)

for file_name in sorted(os.listdir(services_path)):

    file_path = os.path.join(services_path, file_name)

    if os.path.isfile(file_path):
        size = os.path.getsize(file_path)

        print(f"✅ {file_name} ({size} bytes)")

print("=" * 60)
# Out:
# ...
# SERVICES CHECK
# ...
# ✅ airport_transfer.txt (445 bytes)
# ✅ breakfast.txt (517 bytes)
# ✅ gym.txt (334 bytes)
# ✅ laundry.txt (455 bytes)
# ✅ room_service.txt (442 bytes)
# ✅ spa.txt (437 bytes)
# ...

# %%
import os

policies_path = os.path.join(
    "02_Hotel_Knowledge",
    "Policies"
)

print("=" * 60)
print("POLICIES CHECK")
print("=" * 60)

files = sorted(
    file_name
    for file_name in os.listdir(policies_path)
    if os.path.isfile(os.path.join(policies_path, file_name))
)

for file_name in files:
    file_path = os.path.join(policies_path, file_name)
    size = os.path.getsize(file_path)
    print(f"✅ {file_name} ({size} bytes)")

print("=" * 60)
print(f"Total policy files: {len(files)}")
# Out:
# ...
# POLICIES CHECK
# ...
# ✅ check_in_check_out.txt (550 bytes)
# ✅ children_policy.txt (335 bytes)
# ✅ emergency_policy.txt (309 bytes)
# ✅ guest_conduct.txt (321 bytes)
# ✅ identification_policy.txt (401 bytes)
# ✅ lost_and_found.txt (365 bytes)
# ✅ noise_policy.txt (258 bytes)
# ✅ pet_policy.txt (217 bytes)
# ✅ privacy_policy.txt (421 bytes)
# ✅ smoking_policy.txt (259 bytes)
# ...
# Total policy files: 10

# %%
import os

knowledge_path = "02_Hotel_Knowledge"

print("=" * 80)
print("HOTEL AI - FULL KNOWLEDGE BASE AUDIT")
print("=" * 80)

total_files = 0
total_characters = 0
total_words = 0

empty_files = []
small_files = []

for root, dirs, files in os.walk(knowledge_path):

    for file_name in sorted(files):

        file_path = os.path.join(root, file_name)

        # Only analyze text files
        if not file_name.lower().endswith(".txt"):
            continue

        total_files += 1

        with open(file_path, "r", encoding="utf-8") as file:
            content = file.read()

        characters = len(content)
        words = len(content.split())

        total_characters += characters
        total_words += words

        relative_path = os.path.relpath(
            file_path,
            knowledge_path
        )

        print(f"\n📄 {relative_path}")
        print(f"   Characters: {characters}")
        print(f"   Words:      {words}")

        if characters == 0:
            empty_files.append(relative_path)

        elif characters < 200:
            small_files.append(relative_path)


print("\n" + "=" * 80)
print("SUMMARY")
print("=" * 80)

print(f"Total TXT files:       {total_files}")
print(f"Total characters:      {total_characters}")
print(f"Total words:           {total_words}")

print("\nEmpty files:")

if empty_files:
    for file in empty_files:
        print(f"❌ {file}")
else:
    print("✅ None")

print("\nVery small files (<200 characters):")

if small_files:
    for file in small_files:
        print(f"⚠️ {file}")
else:
    print("✅ None")

print("\n" + "=" * 80)
# Out:
# ...
# HOTEL AI - FULL KNOWLEDGE BASE AUDIT
# ...
#
# 📄 Booking\booking_confirmation.txt
#    Characters: 974
#    Words:      137
#
# 📄 Booking\booking_modification.txt
#    Characters: 1398
#    Words:      203
#
# 📄 Booking\booking_policy.txt
#    Characters: 1625
#    Words:      240
#
# 📄 Booking\booking_process.txt
#    Characters: 953
#    Words:      136
#
# 📄 Cancellation\cancellation_policy.txt
#    Characters: 1758
#    Words:      231
#
# 📄 Cancellation\cancellation_process.txt
#    Characters: 1089
#    Words:      145
#
# 📄 Hotel_Information\contact_information.txt
#    Characters: 748
#    Words:      104
#
# 📄 Hotel_Information\hotel_facilities.txt
#    Characters: 1153
#    Words:      165
#
# 📄 Hotel_Information\hotel_information.txt
#    Characters: 542
#    Words:      80
#
# 📄 Payment\payment_methods.txt
#    Characters: 863
#    Words:      122
#
# 📄 Payment\payment_policy.txt
#    Characters: 986
#    Words:      144
#
# 📄 Payment\refund_policy.txt
#    Characters: 935
# ...

# %%
import os

services_path = os.path.join(
    "02_Hotel_Knowledge",
    "Services"
)

file_path = os.path.join(
    services_path,
    "restaurant.txt"
)

restaurant_content = """NILE PEARL HOTEL
RESTAURANT INFORMATION

Restaurant:
Main Restaurant

Known Service:
Daily Breakfast

Breakfast Hours:
7:00 AM - 10:30 AM

Breakfast Price:
450 EGP per person

Breakfast Includes:
- Hot food
- Cold food
- Beverages
- Pastries
- Fresh fruit

Important Information:

The current hotel knowledge base only provides confirmed information about breakfast at the main restaurant.

The current hotel knowledge base does not specify:

- Restaurant opening hours outside breakfast
- Lunch service
- Dinner service
- Restaurant menu
- Individual food prices
- Restaurant reservation requirements
- Restaurant dress code
"""

with open(file_path, "w", encoding="utf-8") as file:
    file.write(restaurant_content)

print("Created successfully:")
print(file_path)
print("Size:", os.path.getsize(file_path), "bytes")
# Out:
# Created successfully:
# 02_Hotel_Knowledge\Services\restaurant.txt
# Size: 661 bytes

# %%
import os

knowledge_path = "02_Hotel_Knowledge"

total_files = 0
total_characters = 0
total_words = 0

print("=" * 70)
print("FINAL KNOWLEDGE BASE AUDIT")
print("=" * 70)

for root, dirs, files in os.walk(knowledge_path):

    for file_name in sorted(files):

        if not file_name.endswith(".txt"):
            continue

        file_path = os.path.join(root, file_name)

        with open(file_path, "r", encoding="utf-8") as file:
            content = file.read()

        total_files += 1
        total_characters += len(content)
        total_words += len(content.split())

print(f"Total TXT files:  {total_files}")
print(f"Total characters: {total_characters}")
print(f"Total words:      {total_words}")

print("=" * 70)

if total_files == 32:
    print("✅ KNOWLEDGE BASE FILE COUNT PASSED")
else:
    print("⚠️ Check file count")

print("✅ No empty files expected")
# Out:
# ...
# FINAL KNOWLEDGE BASE AUDIT
# ...
# Total TXT files:  32
# Total characters: 22601
# Total words:      3225
# ...
# ✅ KNOWLEDGE BASE FILE COUNT PASSED
# ✅ No empty files expected

# %%
print(os.listdir("02_Hotel_Knowledge/Services"))
# Out:
# ['airport_transfer.txt', 'breakfast.txt', 'gym.txt', 'laundry.txt', 'restaurant.txt', 'room_service.txt', 'spa.txt']

# %%
import os

knowledge_path = "02_Hotel_Knowledge"

print("=" * 80)
print("HOTEL AI - CONTENT AUDIT")
print("=" * 80)

file_count = 0

for root, dirs, files in os.walk(knowledge_path):

    for file_name in sorted(files):

        if not file_name.lower().endswith(".txt"):
            continue

        file_path = os.path.join(root, file_name)

        with open(file_path, "r", encoding="utf-8") as file:
            content = file.read().strip()

        relative_path = os.path.relpath(
            file_path,
            knowledge_path
        )

        file_count += 1

        print("\n" + "=" * 80)
        print(f"FILE {file_count}: {relative_path}")
        print("=" * 80)

        print(content[:500])

        if len(content) > 500:
            print("\n... [content continues] ...")

print("\n" + "=" * 80)
print(f"TOTAL FILES AUDITED: {file_count}")
print("=" * 80)
# Out:
# ...
# HOTEL AI - CONTENT AUDIT
# ...
#
# ...
# FILE 1: Booking\booking_confirmation.txt
# ...
# NILE PEARL HOTEL
# BOOKING CONFIRMATION
#
# 1. Reservation Confirmation
#
# A reservation should be confirmed after the required booking information has been provided and the reservation process has been completed.
#
# Guests should keep their booking confirmation details for future reference.
#
#
# 2. Confirmation Information
#
# A booking confirmation should be associated with the reservation details provided during the booking process.
#
# Relevant reservation information may include:
#
# - Guest name
# - Number of gu
#
# ... [content continues] ...
#
# ...
# FILE 2: Booking\booking_modification.txt
# ...
# NILE PEARL HOTEL
# BOOKING MODIFICATION POLICY
#
# 1. Reservation Changes
#
# Guests may contact customer service regarding changes to their reservations.
#
# Reservation changes are subject to availability and hotel approval.
#
#
# 2. Changes to Check-in or Check-out Dates
#
# ...

# %%
import os
import pandas as pd

knowledge_path = "02_Hotel_Knowledge"

print("Knowledge path:", knowledge_path)
print("Exists:", os.path.exists(knowledge_path))
# Out:
# Knowledge path: 02_Hotel_Knowledge
# Exists: True

# %%
import os
import pandas as pd

knowledge_path = "02_Hotel_Knowledge"

documents = []

for root, dirs, files in os.walk(knowledge_path):

    for file_name in sorted(files):

        if not file_name.lower().endswith(".txt"):
            continue

        file_path = os.path.join(root, file_name)

        with open(file_path, "r", encoding="utf-8") as file:
            content = file.read().strip()

        relative_path = os.path.relpath(
            file_path,
            knowledge_path
        )

        parts = relative_path.split(os.sep)

        domain = parts[0]
        source = parts[-1]

        documents.append({
            "source": source,
            "domain": domain,
            "content": content,
            "language": "English"
        })

knowledge_df = pd.DataFrame(documents)

print("Documents loaded:", len(knowledge_df))

knowledge_df.head()
# Out:
# Documents loaded: 32
#                      source        domain  \
# 0  booking_confirmation.txt       Booking
# 1  booking_modification.txt       Booking
# 2        booking_policy.txt       Booking
# 3       booking_process.txt       Booking
# 4   cancellation_policy.txt  Cancellation
#
#                                              content language
# 0  NILE PEARL HOTEL\nBOOKING CONFIRMATION\n\n1. R...  English
# 1  NILE PEARL HOTEL\nBOOKING MODIFICATION POLICY\...  English
# 2  NILE PEARL HOTEL\nBOOKING POLICY\n\n1. Room Re...  English
# 3  NILE PEARL HOTEL\nBOOKING PROCESS\n\n1. Select...  English
# 4  NILE PEARL HOTEL\nCANCELLATION POLICY\n\n1. Ca...  English

# %%
# Add unique document IDs

knowledge_df.insert(
    0,
    "document_id",
    [f"DOC{i:03d}" for i in range(1, len(knowledge_df) + 1)]
)

# Map each source file to a specific category

category_map = {
    # Booking
    "booking_confirmation.txt": "Booking",
    "booking_modification.txt": "Booking",
    "booking_policy.txt": "Booking",
    "booking_process.txt": "Booking",

    # Cancellation
    "cancellation_policy.txt": "Cancellation",
    "cancellation_process.txt": "Cancellation",

    # Hotel Information
    "contact_information.txt": "Hotel Information",
    "hotel_facilities.txt": "Hotel Facilities",
    "hotel_information.txt": "Hotel Information",

    # Payment
    "payment_methods.txt": "Payment",
    "payment_policy.txt": "Payment",
    "refund_policy.txt": "Refund",

    # Policies
    "check_in_check_out.txt": "Check-in / Check-out",
    "children_policy.txt": "Children",
    "emergency_policy.txt": "Emergency",
    "guest_conduct.txt": "Guest Conduct",
    "identification_policy.txt": "Identification",
    "lost_and_found.txt": "Lost and Found",
    "noise_policy.txt": "Noise",
    "pet_policy.txt": "Pets",
    "privacy_policy.txt": "Privacy",
    "smoking_policy.txt": "Smoking",

    # Rooms
    "room_amenities.txt": "Room Amenities",
    "room_policies.txt": "Room Policies",
    "room_types.txt": "Room Types",

    # Services
    "airport_transfer.txt": "Airport Transfer",
    "breakfast.txt": "Breakfast",
    "gym.txt": "Gym",
    "laundry.txt": "Laundry",
    "restaurant.txt": "Restaurant",
    "room_service.txt": "Room Service",
    "spa.txt": "Spa"
}

knowledge_df["category"] = knowledge_df["source"].map(category_map)

print("Documents:", len(knowledge_df))
print("\nMissing categories:")

print(
    knowledge_df[
        knowledge_df["category"].isna()
    ][["source", "domain"]]
)

knowledge_df.head()
# Out:
# Documents: 32
#
# Missing categories:
# Empty DataFrame
# Columns: [source, domain]
# Index: []
#   document_id                    source        domain  \
# 0      DOC001  booking_confirmation.txt       Booking
# 1      DOC002  booking_modification.txt       Booking
# 2      DOC003        booking_policy.txt       Booking
# 3      DOC004       booking_process.txt       Booking
# 4      DOC005   cancellation_policy.txt  Cancellation
#
#                                              content language      category
# 0  NILE PEARL HOTEL\nBOOKING CONFIRMATION\n\n1. R...  English       Booking
# 1  NILE PEARL HOTEL\nBOOKING MODIFICATION POLICY\...  English       Booking
# 2  NILE PEARL HOTEL\nBOOKING POLICY\n\n1. Room Re...  English       Booking
# 3  NILE PEARL HOTEL\nBOOKING PROCESS\n\n1. Select...  English       Booking
# 4  NILE PEARL HOTEL\nCANCELLATION POLICY\n\n1. Ca...  English  Cancellation

# %%
faq_columns = [
    "faq_id",
    "intent_id",
    "category",
    "language",
    "question",
    "answer",
    "source",
    "question_type",
    "difficulty"
]

faq_df = pd.DataFrame(columns=faq_columns)

print("FAQ Schema:")
print(faq_df.columns.tolist())

print("\nNumber of columns:", len(faq_df.columns))
# Out:
# FAQ Schema:
# ['faq_id', 'intent_id', 'category', 'language', 'question', 'answer', 'source', 'question_type', 'difficulty']
#
# Number of columns: 9

# %%
intent_catalog = [
    # =========================
    # HOTEL INFORMATION
    # =========================

    {
        "intent_id": "INT001",
        "intent_name": "hotel_location",
        "category": "Hotel Information",
        "source": "hotel_information.txt"
    },

    {
        "intent_id": "INT002",
        "intent_name": "hotel_category",
        "category": "Hotel Information",
        "source": "hotel_information.txt"
    },

    {
        "intent_id": "INT003",
        "intent_name": "reception_availability",
        "category": "Hotel Information",
        "source": "hotel_information.txt"
    },

    # =========================
    # CHECK-IN / CHECK-OUT
    # =========================

    {
        "intent_id": "INT004",
        "intent_name": "check_in_time",
        "category": "Check-in / Check-out",
        "source": "check_in_check_out.txt"
    },

    {
        "intent_id": "INT005",
        "intent_name": "check_out_time",
        "category": "Check-in / Check-out",
        "source": "check_in_check_out.txt"
    },

    {
        "intent_id": "INT006",
        "intent_name": "early_check_in",
        "category": "Check-in / Check-out",
        "source": "check_in_check_out.txt"
    },

    {
        "intent_id": "INT007",
        "intent_name": "late_check_out",
        "category": "Check-in / Check-out",
        "source": "check_in_check_out.txt"
    },

    {
        "intent_id": "INT008",
        "intent_name": "identification_required",
        "category": "Identification",
        "source": "identification_policy.txt"
    },

    # =========================
    # ROOMS
    # =========================

    {
        "intent_id": "INT009",
        "intent_name": "available_room_types",
        "category": "Room Types",
        "source": "room_types.txt"
    },

    {
        "intent_id": "INT010",
        "intent_name": "room_capacity",
        "category": "Room Policies",
        "source": "room_policies.txt"
    },

    {
        "intent_id": "INT011",
        "intent_name": "room_amenities",
        "category": "Room Amenities",
        "source": "room_amenities.txt"
    },

    {
        "intent_id": "INT012",
        "intent_name": "children_room_accommodation",
        "category": "Room Policies",
        "source": "room_policies.txt"
    },

    # =========================
    # BOOKING
    # =========================

    {
        "intent_id": "INT013",
        "intent_name": "booking_process",
        "category": "Booking",
        "source": "booking_process.txt"
    },

    {
        "intent_id": "INT014",
        "intent_name": "booking_required_information",
        "category": "Booking",
        "source": "booking_policy.txt"
    },

    {
        "intent_id": "INT015",
        "intent_name": "booking_modification",
        "category": "Booking",
        "source": "booking_modification.txt"
    },

    {
        "intent_id": "INT016",
        "intent_name": "booking_confirmation",
        "category": "Booking",
        "source": "booking_confirmation.txt"
    },

    # =========================
    # CANCELLATION
    # =========================

    {
        "intent_id": "INT017",
        "intent_name": "cancellation_process",
        "category": "Cancellation",
        "source": "cancellation_process.txt"
    },

    {
        "intent_id": "INT018",
        "intent_name": "cancellation_policy",
        "category": "Cancellation",
        "source": "cancellation_policy.txt"
    },

    {
        "intent_id": "INT019",
        "intent_name": "cancellation_fees",
        "category": "Cancellation",
        "source": "cancellation_policy.txt"
    },

    # =========================
    # PAYMENT / REFUND
    # =========================

    {
        "intent_id": "INT020",
        "intent_name": "accepted_payment_methods",
        "category": "Payment",
        "source": "payment_methods.txt"
    },

    {
        "intent_id": "INT021",
        "intent_name": "payment_requirements",
        "category": "Payment",
        "source": "payment_policy.txt"
    },

    {
        "intent_id": "INT022",
        "intent_name": "additional_charges",
        "category": "Payment",
        "source": "payment_policy.txt"
    },

    {
        "intent_id": "INT023",
        "intent_name": "refund_eligibility",
        "category": "Refund",
        "source": "refund_policy.txt"
    },

    {
        "intent_id": "INT024",
        "intent_name": "refund_processing",
        "category": "Refund",
        "source": "refund_policy.txt"
    },

    # =========================
    # SERVICES
    # =========================

    {
        "intent_id": "INT025",
        "intent_name": "breakfast_hours",
        "category": "Breakfast",
        "source": "breakfast.txt"
    },

    {
        "intent_id": "INT026",
        "intent_name": "breakfast_price",
        "category": "Breakfast",
        "source": "breakfast.txt"
    },

    {
        "intent_id": "INT027",
        "intent_name": "room_service",
        "category": "Room Service",
        "source": "room_service.txt"
    },

    {
        "intent_id": "INT028",
        "intent_name": "airport_transfer",
        "category": "Airport Transfer",
        "source": "airport_transfer.txt"
    },

    {
        "intent_id": "INT029",
        "intent_name": "laundry_service",
        "category": "Laundry",
        "source": "laundry.txt"
    },

    {
        "intent_id": "INT030",
        "intent_name": "spa_service",
        "category": "Spa",
        "source": "spa.txt"
    },

    {
        "intent_id": "INT031",
        "intent_name": "gym_availability",
        "category": "Gym",
        "source": "gym.txt"
    },

    {
        "intent_id": "INT032",
        "intent_name": "restaurant_information",
        "category": "Restaurant",
        "source": "restaurant.txt"
    },

    # =========================
    # FACILITIES
    # =========================

    {
        "intent_id": "INT033",
        "intent_name": "wifi_availability",
        "category": "Hotel Facilities",
        "source": "hotel_facilities.txt"
    },

    {
        "intent_id": "INT034",
        "intent_name": "parking_availability",
        "category": "Hotel Facilities",
        "source": "hotel_facilities.txt"
    },

    {
        "intent_id": "INT035",
        "intent_name": "swimming_pool",
        "category": "Hotel Facilities",
        "source": "hotel_facilities.txt"
    },

    # =========================
    # POLICIES
    # =========================

    {
        "intent_id": "INT036",
        "intent_name": "pet_policy",
        "category": "Pets",
        "source": "pet_policy.txt"
    },

    {
        "intent_id": "INT037",
        "intent_name": "smoking_policy",
        "category": "Smoking",
        "source": "smoking_policy.txt"
    },

    {
        "intent_id": "INT038",
        "intent_name": "children_policy",
        "category": "Children",
        "source": "children_policy.txt"
    },

    {
        "intent_id": "INT039",
        "intent_name": "lost_and_found",
        "category": "Lost and Found",
        "source": "lost_and_found.txt"
    },

    {
        "intent_id": "INT040",
        "intent_name": "noise_policy",
        "category": "Noise",
        "source": "noise_policy.txt"
    },

    {
        "intent_id": "INT041",
        "intent_name": "guest_conduct",
        "category": "Guest Conduct",
        "source": "guest_conduct.txt"
    },

    {
        "intent_id": "INT042",
        "intent_name": "privacy_policy",
        "category": "Privacy",
        "source": "privacy_policy.txt"
    },

    {
        "intent_id": "INT043",
        "intent_name": "emergency_assistance",
        "category": "Emergency",
        "source": "emergency_policy.txt"
    }
]

# %%
intent_df = pd.DataFrame(intent_catalog)

print("Total intents:", len(intent_df))

intent_df.head(10)
# Out:
# Total intents: 43
#   intent_id              intent_name              category  \
# 0    INT001           hotel_location     Hotel Information
# 1    INT002           hotel_category     Hotel Information
# 2    INT003   reception_availability     Hotel Information
# 3    INT004            check_in_time  Check-in / Check-out
# 4    INT005           check_out_time  Check-in / Check-out
# 5    INT006           early_check_in  Check-in / Check-out
# 6    INT007           late_check_out  Check-in / Check-out
# 7    INT008  identification_required        Identification
# 8    INT009     available_room_types            Room Types
# 9    INT010            room_capacity         Room Policies
#
#                       source
# 0      hotel_information.txt
# 1      hotel_information.txt
# 2      hotel_information.txt
# 3     check_in_check_out.txt
# 4     check_in_check_out.txt
# 5     check_in_check_out.txt
# 6     check_in_check_out.txt
# 7  identification_policy.txt
# ...

# %%
# Validate intent sources

available_sources = set(knowledge_df["source"])

intent_df["source_exists"] = intent_df["source"].isin(available_sources)

print("Total intents:", len(intent_df))
print("Valid sources:", intent_df["source_exists"].sum())
print("Missing sources:", (~intent_df["source_exists"]).sum())

print("\nMissing source files:")

print(
    intent_df[
        ~intent_df["source_exists"]
    ][
        ["intent_id", "intent_name", "source"]
    ]
)
# Out:
# Total intents: 43
# Valid sources: 43
# Missing sources: 0
#
# Missing source files:
# Empty DataFrame
# Columns: [intent_id, intent_name, source]
# Index: []

# %%
intent_distribution = (
    intent_df["category"]
    .value_counts()
    .sort_index()
)

print("=" * 60)
print("INTENT DISTRIBUTION")
print("=" * 60)

print(intent_distribution)

print("\nTotal categories:", intent_df["category"].nunique())
print("Total intents:", len(intent_df))
# Out:
# ...
# INTENT DISTRIBUTION
# ...
# category
# Airport Transfer        1
# Booking                 4
# Breakfast               2
# Cancellation            3
# Check-in / Check-out    4
# Children                1
# Emergency               1
# Guest Conduct           1
# Gym                     1
# Hotel Facilities        3
# Hotel Information       3
# Identification          1
# Laundry                 1
# Lost and Found          1
# Noise                   1
# Payment                 3
# Pets                    1
# Privacy                 1
# Refund                  2
# Restaurant              1
# Room Amenities          1
# Room Policies           2
# Room Service            1
# Room Types              1
# Smoking                 1
# Spa                     1
# Name: count, dtype: int64
#
# Total categories: 26
# Total intents: 43

# %%
print("=" * 70)
print("FINAL INTENT CATALOG VALIDATION")
print("=" * 70)

checks = {
    "Total intents": len(intent_df),
    "Unique intent IDs": intent_df["intent_id"].nunique(),
    "Unique intent names": intent_df["intent_name"].nunique(),
    "Unique categories": intent_df["category"].nunique(),
    "Missing intent IDs": intent_df["intent_id"].isna().sum(),
    "Missing intent names": intent_df["intent_name"].isna().sum(),
    "Missing categories": intent_df["category"].isna().sum(),
    "Missing sources": intent_df["source"].isna().sum(),
}

for name, value in checks.items():
    print(f"{name}: {value}")

print("=" * 70)

passed = (
    checks["Total intents"] == 43
    and checks["Unique intent IDs"] == 43
    and checks["Unique intent names"] == 43
    and checks["Missing intent IDs"] == 0
    and checks["Missing intent names"] == 0
    and checks["Missing categories"] == 0
    and checks["Missing sources"] == 0
)

if passed:
    print("✅ INTENT CATALOG PASSED")
    print("✅ Ready for FAQ generation design")
else:
    print("⚠️ INTENT CATALOG NEEDS REVIEW")
# Out:
# ...
# FINAL INTENT CATALOG VALIDATION
# ...
# Total intents: 43
# Unique intent IDs: 43
# Unique intent names: 43
# Unique categories: 26
# Missing intent IDs: 0
# Missing intent names: 0
# Missing categories: 0
# Missing sources: 0
# ...
# ✅ INTENT CATALOG PASSED
# ✅ Ready for FAQ generation design

# %%
question_matrix = {
    "Direct": 3,
    "Paraphrased": 3,
    "Scenario": 2
}

languages = [
    "English",
    "Arabic",
    "French",
    "Russian"
]

total_questions_per_intent = sum(question_matrix.values())

total_english_questions = (
    len(intent_df) * total_questions_per_intent
)

total_all_languages = (
    total_english_questions * len(languages)
)

print("=" * 70)
print("QUESTION GENERATION MATRIX")
print("=" * 70)

print("Question Types:")

for question_type, count in question_matrix.items():
    print(f"- {question_type}: {count}")

print("\nLanguages:")

for language in languages:
    print(f"- {language}")

print("\nTotal intents:", len(intent_df))
print("Questions per intent:", total_questions_per_intent)
print("English questions:", total_english_questions)
print("Total FAQ rows:", total_all_languages)
# Out:
# ...
# QUESTION GENERATION MATRIX
# ...
# Question Types:
# - Direct: 3
# - Paraphrased: 3
# - Scenario: 2
#
# Languages:
# - English
# - Arabic
# - French
# - Russian
#
# Total intents: 43
# Questions per intent: 8
# English questions: 344
# Total FAQ rows: 1376

# %%
generation_columns = [
    "faq_id",
    "intent_id",
    "intent_name",
    "category",
    "language",
    "question_type",
    "difficulty",
    "question",
    "answer",
    "source"
]

generation_df = pd.DataFrame(columns=generation_columns)

print("=" * 70)
print("FAQ GENERATION DATASET")
print("=" * 70)

print("Columns:", len(generation_df.columns))
print("Target rows:", total_all_languages)

print("\nSchema:")
for column in generation_df.columns:
    print(f"- {column}")
# Out:
# ...
# FAQ GENERATION DATASET
# ...
# Columns: 10
# Target rows: 1376
#
# Schema:
# - faq_id
# - intent_id
# - intent_name
# - category
# - language
# - question_type
# - difficulty
# - question
# - answer
# - source

# %%
generation_plan = []

faq_counter = 1

for _, intent in intent_df.iterrows():

    for language in languages:

        for question_type, count in question_matrix.items():

            for _ in range(count):

                generation_plan.append({
                    "faq_id": f"FAQ{faq_counter:04d}",
                    "intent_id": intent["intent_id"],
                    "intent_name": intent["intent_name"],
                    "category": intent["category"],
                    "language": language,
                    "question_type": question_type,
                    "difficulty": "Easy",
                    "question": "",
                    "answer": "",
                    "source": intent["source"]
                })

                faq_counter += 1

generation_plan_df = pd.DataFrame(generation_plan)

print("=" * 70)
print("FAQ GENERATION PLAN")
print("=" * 70)

print("Total planned rows:", len(generation_plan_df))
print("Expected rows:", total_all_languages)

print("\nLanguages:")
print(generation_plan_df["language"].value_counts())

print("\nQuestion Types:")
print(generation_plan_df["question_type"].value_counts())

print("\nFirst 10 rows:")
generation_plan_df.head(10)
# Out:
# ...
# FAQ GENERATION PLAN
# ...
# Total planned rows: 1376
# Expected rows: 1376
#
# Languages:
# language
# English    344
# Arabic     344
# French     344
# Russian    344
# Name: count, dtype: int64
#
# Question Types:
# question_type
# Direct         516
# Paraphrased    516
# Scenario       344
# Name: count, dtype: int64
#
# First 10 rows:
#     faq_id intent_id     intent_name           category language  \
# 0  FAQ0001    INT001  hotel_location  Hotel Information  English
# 1  FAQ0002    INT001  hotel_location  Hotel Information  English
# 2  FAQ0003    INT001  hotel_location  Hotel Information  English
# 3  FAQ0004    INT001  hotel_location  Hotel Information  English
# 4  FAQ0005    INT001  hotel_location  Hotel Information  English
# 5  FAQ0006    INT001  hotel_location  Hotel Information  English
# 6  FAQ0007    INT001  hotel_location  Hotel Information  English
# 7  FAQ0008    INT001  hotel_location  Hotel Information  English
# ...

# %%
# Build a lookup for knowledge documents

knowledge_lookup = {}

for _, row in knowledge_df.iterrows():
    knowledge_lookup[row["source"]] = row["content"]

print("Knowledge documents available:", len(knowledge_lookup))

# Check that every intent has its source available

missing_sources = []

for _, intent in intent_df.iterrows():

    if intent["source"] not in knowledge_lookup:
        missing_sources.append(intent["source"])

print("Missing intent sources:", len(missing_sources))

if missing_sources:
    print(missing_sources)
else:
    print("✅ All intent sources are available")
# Out:
# Knowledge documents available: 32
# Missing intent sources: 0
# ✅ All intent sources are available

# %%
ground_truth_catalog = {
    "INT001": "Nile Pearl Hotel is located in Cairo, Egypt.",
    "INT002": "Nile Pearl Hotel is a 5-star hotel.",
    "INT003": "Hotel reception operates 24/7.",

    "INT004": "Standard check-in time is 3:00 PM.",
    "INT005": "Standard check-out time is 12:00 PM.",
    "INT006": "Early check-in is subject to room availability and hotel approval.",
    "INT007": "Late check-out is subject to availability and may incur an additional fee.",
    "INT008": "Guests are required to provide valid identification documents during check-in.",

    "INT009": "Nile Pearl Hotel offers Standard, Deluxe, Superior, Family, and Executive rooms.",
    "INT010": "Room capacity depends on the room type. Standard and Deluxe rooms accommodate up to 2 guests, Superior rooms up to 3 guests, and Family rooms up to 4 guests. Executive Room capacity is not specified.",
    "INT011": "Room amenities vary by room type and may include private bathrooms, Wi-Fi, air conditioning, televisions, comfortable beds, and upgraded amenities.",
    "INT012": "Children are welcome. Extra beds or additional accommodation are subject to room capacity and availability.",

    "INT013": "The booking process includes selecting dates, selecting a room, providing guest information, reviewing the reservation, and confirming the booking.",
    "INT014": "Booking information may include the guest's full name, number of guests, check-in date, check-out date, selected room type, contact information, and payment information when required.",
    "INT015": "Guests may contact customer service to request reservation changes. Changes are subject to availability and hotel approval.",
    "INT016": "A reservation should be confirmed after the required booking information has been provided and the reservation process has been completed.",

    "INT017": "Guests can contact customer service to request cancellation assistance and should provide the relevant reservation details.",
    "INT018": "Cancellation eligibility depends on the conditions associated with the reservation.",
    "INT019": "Any applicable cancellation fees depend on the cancellation conditions associated with the reservation.",

    "INT020": "The current hotel knowledge base does not specify the exact payment methods accepted by the hotel. Guests should contact customer service for current information.",
    "INT021": "Payment requirements depend on the selected reservation and applicable hotel policies.",
    "INT022": "Additional charges may apply for certain hotel services or damages to hotel property.",

    "INT023": "Refund eligibility depends on the conditions associated with the reservation.",
    "INT024": "Eligible refunds are processed according to the applicable payment and refund conditions. The current knowledge base does not specify a fixed refund processing time.",

    "INT025": "Daily breakfast is available from 7:00 AM to 10:30 AM at the main restaurant.",
    "INT026": "Breakfast costs 450 EGP per person.",
    "INT027": "Room service is available 24/7. Guests can order food and beverages directly to their rooms.",
    "INT028": "Airport transfer is available upon request and costs 800 EGP per trip.",
    "INT029": "Laundry and dry cleaning are available daily and laundry service costs 200 EGP per kilogram.",
    "INT030": "Spa treatments are available from 9:00 AM to 10:00 PM and cost 1,200 EGP per session.",
    "INT031": "The hotel gym is available 24/7 for hotel guests.",
    "INT032": "The main restaurant provides daily breakfast from 7:00 AM to 10:30 AM. The current knowledge base does not specify restaurant services outside breakfast.",

    "INT033": "Free Wi-Fi is available 24/7 in all guest rooms and public areas.",
    "INT034": "Parking is available for hotel guests.",
    "INT035": "The swimming pool is available for hotel guests from 7:00 AM to 9:00 PM.",

    "INT036": "Pets are not allowed inside the hotel, including guest rooms and hotel facilities.",
    "INT037": "Smoking is not permitted inside guest rooms or indoor public areas. Designated smoking areas are available.",
    "INT038": "Children are welcome. Extra beds or additional accommodation are subject to room capacity and availability.",
    "INT039": "Guests who lose an item should contact the front desk. Items found on hotel property are handled by the hotel's Lost and Found department.",
    "INT040": "Guests should maintain reasonable noise levels, especially during nighttime hours.",
    "INT041": "Guests are expected to respect hotel property, staff, and other guests. Damage to hotel property may result in additional charges.",
    "INT042": "Guest information is handled according to the hotel's privacy and security procedures. The current knowledge base does not provide the complete privacy policy or specific data retention periods.",
    "INT043": "In case of an emergency, guests should contact the hotel reception immediately. Reception operates 24/7."
}

print("Ground truth answers:", len(ground_truth_catalog))
# Out:
# Ground truth answers: 43

# %%
missing_ground_truth = []

for intent_id in intent_df["intent_id"]:

    if intent_id not in ground_truth_catalog:
        missing_ground_truth.append(intent_id)

print("Total intents:", len(intent_df))
print("Ground truth answers:", len(ground_truth_catalog))
print("Missing answers:", len(missing_ground_truth))

if missing_ground_truth:
    print("⚠️ Missing:", missing_ground_truth)
else:
    print("✅ ALL 43 INTENTS HAVE GROUND TRUTH ANSWERS")
# Out:
# Total intents: 43
# Ground truth answers: 43
# Missing answers: 0
# ✅ ALL 43 INTENTS HAVE GROUND TRUTH ANSWERS

# %%
print("=" * 70)
print("POTENTIAL DUPLICATE / OVERLAPPING INTENTS")
print("=" * 70)

for intent_id in ["INT012", "INT038"]:
    row = intent_df[intent_df["intent_id"] == intent_id]

    if not row.empty:
        print("\nIntent ID:", intent_id)
        print("Name:", row.iloc[0]["intent_name"])
        print("Category:", row.iloc[0]["category"])
        print("Source:", row.iloc[0]["source"])
        print("Answer:", ground_truth_catalog[intent_id])
# Out:
# ...
# POTENTIAL DUPLICATE / OVERLAPPING INTENTS
# ...
#
# Intent ID: INT012
# Name: children_room_accommodation
# Category: Room Policies
# Source: room_policies.txt
# Answer: Children are welcome. Extra beds or additional accommodation are subject to room capacity and availability.
#
# Intent ID: INT038
# Name: children_policy
# Category: Children
# Source: children_policy.txt
# Answer: Children are welcome. Extra beds or additional accommodation are subject to room capacity and availability.

# %%
intent_df_clean = intent_df[
    intent_df["intent_id"] != "INT012"
].copy()

intent_df_clean = intent_df_clean.reset_index(drop=True)

print("=" * 70)
print("CLEAN INTENT CATALOG")
print("=" * 70)

print("Original intents:", len(intent_df))
print("Clean intents:", len(intent_df_clean))
print("Removed intents:", len(intent_df) - len(intent_df_clean))
# Out:
# ...
# CLEAN INTENT CATALOG
# ...
# Original intents: 43
# Clean intents: 42
# Removed intents: 1

# %%
ground_truth_catalog.pop("INT012", None)

print("Ground truth answers:", len(ground_truth_catalog))
# Out:
# Ground truth answers: 42

# %%
generation_plan = []

faq_counter = 1

for _, intent in intent_df_clean.iterrows():

    for language in languages:

        for question_type, count in question_matrix.items():

            for _ in range(count):

                generation_plan.append({
                    "faq_id": f"FAQ{faq_counter:04d}",
                    "intent_id": intent["intent_id"],
                    "intent_name": intent["intent_name"],
                    "category": intent["category"],
                    "language": language,
                    "question_type": question_type,
                    "difficulty": "Easy",
                    "question": "",
                    "answer": "",
                    "source": intent["source"]
                })

                faq_counter += 1

generation_plan_df = pd.DataFrame(generation_plan)

print("=" * 70)
print("UPDATED FAQ GENERATION PLAN")
print("=" * 70)

print("Total intents:", len(intent_df_clean))
print("Total planned rows:", len(generation_plan_df))

print("\nLanguages:")
print(generation_plan_df["language"].value_counts())

print("\nQuestion Types:")
print(generation_plan_df["question_type"].value_counts())
# Out:
# ...
# UPDATED FAQ GENERATION PLAN
# ...
# Total intents: 42
# Total planned rows: 1344
#
# Languages:
# language
# English    336
# Arabic     336
# French     336
# Russian    336
# Name: count, dtype: int64
#
# Question Types:
# question_type
# Direct         504
# Paraphrased    504
# Scenario       336
# Name: count, dtype: int64

# %%
generation_plan_df["ground_truth"] = (
    generation_plan_df["intent_id"]
    .map(ground_truth_catalog)
)

print("=" * 70)
print("GROUND TRUTH MAPPING")
print("=" * 70)

print("Total rows:", len(generation_plan_df))
print(
    "Missing ground truth:",
    generation_plan_df["ground_truth"].isna().sum()
)

print("\nSample:")
print(
    generation_plan_df[
        [
            "faq_id",
            "intent_id",
            "intent_name",
            "language",
            "question_type",
            "ground_truth"
        ]
    ].head(10).to_string(index=False)
)
# Out:
# ...
# GROUND TRUTH MAPPING
# ...
# Total rows: 1344
# Missing ground truth: 0
#
# Sample:
#  faq_id intent_id    intent_name language question_type                                 ground_truth
# FAQ0001    INT001 hotel_location  English        Direct Nile Pearl Hotel is located in Cairo, Egypt.
# FAQ0002    INT001 hotel_location  English        Direct Nile Pearl Hotel is located in Cairo, Egypt.
# FAQ0003    INT001 hotel_location  English        Direct Nile Pearl Hotel is located in Cairo, Egypt.
# FAQ0004    INT001 hotel_location  English   Paraphrased Nile Pearl Hotel is located in Cairo, Egypt.
# FAQ0005    INT001 hotel_location  English   Paraphrased Nile Pearl Hotel is located in Cairo, Egypt.
# FAQ0006    INT001 hotel_location  English   Paraphrased Nile Pearl Hotel is located in Cairo, Egypt.
# FAQ0007    INT001 hotel_location  English      Scenario Nile Pearl Hotel is located in Cairo, Egypt.
# ...

# %%
# ============================================================
# MULTILINGUAL GROUND TRUTH STRUCTURE
# ============================================================

languages = [
    "English",
    "Arabic",
    "French",
    "Russian"
]

multilingual_ground_truth = {}

for intent_id, english_answer in ground_truth_catalog.items():

    multilingual_ground_truth[intent_id] = {
        "English": english_answer,
        "Arabic": "",
        "French": "",
        "Russian": ""
    }

print("=" * 70)
print("MULTILINGUAL GROUND TRUTH")
print("=" * 70)

print("Total intents:", len(multilingual_ground_truth))
print("Languages per intent:", len(languages))

sample_intent = "INT001"

print("\nSample:")
print("Intent:", sample_intent)

for language in languages:
    print(
        f"{language}:",
        multilingual_ground_truth[sample_intent][language]
    )
# Out:
# ...
# MULTILINGUAL GROUND TRUTH
# ...
# Total intents: 42
# Languages per intent: 4
#
# Sample:
# Intent: INT001
# English: Nile Pearl Hotel is located in Cairo, Egypt.
# Arabic:
# French:
# Russian:

# %%
# ============================================================
# MULTILINGUAL ANSWER TRANSLATION PLAN
# ============================================================

translation_plan = []

for intent_id, answers in multilingual_ground_truth.items():

    intent_row = intent_df_clean[
        intent_df_clean["intent_id"] == intent_id
    ].iloc[0]

    for language in ["Arabic", "French", "Russian"]:

        translation_plan.append({
            "intent_id": intent_id,
            "intent_name": intent_row["intent_name"],
            "category": intent_row["category"],
            "source": intent_row["source"],
            "language": language,
            "english_answer": answers["English"],
            "translated_answer": ""
        })

translation_plan_df = pd.DataFrame(translation_plan)

print("=" * 70)
print("ANSWER TRANSLATION PLAN")
print("=" * 70)

print("Total translation rows:", len(translation_plan_df))
print("Expected:", 42 * 3)

print("\nLanguages:")
print(
    translation_plan_df["language"].value_counts()
)

print("\nSample:")
print(
    translation_plan_df.head(10).to_string(index=False)
)
# Out:
# ...
# ANSWER TRANSLATION PLAN
# ...
# Total translation rows: 126
# Expected: 126
#
# Languages:
# language
# Arabic     42
# French     42
# Russian    42
# Name: count, dtype: int64
#
# Sample:
# intent_id            intent_name             category                 source language                               english_answer translated_answer
#    INT001         hotel_location    Hotel Information  hotel_information.txt   Arabic Nile Pearl Hotel is located in Cairo, Egypt.
#    INT001         hotel_location    Hotel Information  hotel_information.txt   French Nile Pearl Hotel is located in Cairo, Egypt.
#    INT001         hotel_location    Hotel Information  hotel_information.txt  Russian Nile Pearl Hotel is located in Cairo, Egypt.
#    INT002         hotel_category    Hotel Information  hotel_information.txt   Arabic          Nile Pearl Hotel is a 5-star hotel.
# ...

# %%
# ============================================================
# MULTILINGUAL GROUND TRUTH ANSWERS
# ============================================================

localized_answers = {

    "INT001": {
        "Arabic": "يقع فندق نايل بيرل في القاهرة، مصر.",
        "French": "Le Nile Pearl Hotel est situé au Caire, en Égypte.",
        "Russian": "Отель Nile Pearl расположен в Каире, Египет."
    },

    "INT002": {
        "Arabic": "فندق نايل بيرل هو فندق خمس نجوم.",
        "French": "Le Nile Pearl Hotel est un hôtel 5 étoiles.",
        "Russian": "Nile Pearl Hotel — пятизвездочный отель."
    },

    "INT003": {
        "Arabic": "يعمل مكتب استقبال الفندق على مدار 24 ساعة طوال أيام الأسبوع.",
        "French": "La réception de l'hôtel est ouverte 24 heures sur 24, 7 jours sur 7.",
        "Russian": "Стойка регистрации отеля работает круглосуточно."
    },

    "INT004": {
        "Arabic": "وقت تسجيل الوصول القياسي هو الساعة 3:00 مساءً.",
        "French": "L'heure standard d'enregistrement est 15h00.",
        "Russian": "Стандартное время регистрации заезда — 15:00."
    },

    "INT005": {
        "Arabic": "وقت تسجيل المغادرة القياسي هو الساعة 12:00 ظهرًا.",
        "French": "L'heure standard de départ est 12h00.",
        "Russian": "Стандартное время выезда — 12:00."
    },

    "INT006": {
        "Arabic": "تسجيل الوصول المبكر يخضع لتوافر الغرفة وموافقة الفندق.",
        "French": "L'enregistrement anticipé dépend de la disponibilité de la chambre et de l'approbation de l'hôtel.",
        "Russian": "Ранний заезд зависит от наличия свободных номеров и одобрения отеля."
    },

    "INT007": {
        "Arabic": "تسجيل المغادرة المتأخر يخضع للتوافر وقد تترتب عليه رسوم إضافية.",
        "French": "Le départ tardif dépend des disponibilités et peut entraîner des frais supplémentaires.",
        "Russian": "Поздний выезд зависит от наличия возможности и может быть платным."
    },

    "INT008": {
        "Arabic": "يُطلب من الضيوف تقديم وثائق هوية سارية عند تسجيل الوصول.",
        "French": "Les clients doivent présenter une pièce d'identité valide lors de l'enregistrement.",
        "Russian": "При регистрации заезда гости должны предъявить действительный документ, удостоверяющий личность."
    },

    "INT009": {
        "Arabic": "يوفر فندق نايل بيرل غرفًا من الأنواع التالية: Standard وDeluxe وSuperior وFamily وExecutive.",
        "French": "Le Nile Pearl Hotel propose les types de chambres suivants : Standard, Deluxe, Superior, Family et Executive.",
        "Russian": "Nile Pearl Hotel предлагает следующие типы номеров: Standard, Deluxe, Superior, Family и Executive."
    },

    "INT010": {
        "Arabic": "تعتمد سعة الغرفة على نوعها. تستوعب غرفتا Standard وDeluxe ما يصل إلى ضيفين، وتستوعب Superior ما يصل إلى 3 ضيوف، وFamily ما يصل إلى 4 ضيوف. سعة غرفة Executive غير محددة في قاعدة المعرفة الحالية.",
        "French": "La capacité dépend du type de chambre. Les chambres Standard et Deluxe peuvent accueillir jusqu'à 2 personnes, la Superior jusqu'à 3 personnes et la Family jusqu'à 4 personnes. La capacité de la chambre Executive n'est pas précisée dans la base de connaissances actuelle.",
        "Russian": "Вместимость зависит от типа номера. Номера Standard и Deluxe рассчитаны максимум на 2 гостей, Superior — на 3 гостей, а Family — на 4 гостей. Вместимость номера Executive в текущей базе знаний не указана."
    },

    "INT011": {
        "Arabic": "تختلف وسائل الراحة حسب نوع الغرفة، وقد تشمل الحمام الخاص وخدمة الواي فاي وتكييف الهواء والتلفزيون والأسرة المريحة ووسائل الراحة المطورة.",
        "French": "Les équipements varient selon le type de chambre et peuvent inclure une salle de bains privative, le Wi-Fi, la climatisation, une télévision, des lits confortables et des équipements améliorés.",
        "Russian": "Удобства зависят от типа номера и могут включать отдельную ванную комнату, Wi-Fi, кондиционер, телевизор, удобную кровать и улучшенные удобства."
    },

    "INT012": {
        "Arabic": "الأطفال مرحب بهم. تخضع الأسرّة الإضافية أو أماكن الإقامة الإضافية لسعة الغرفة والتوافر.",
        "French": "Les enfants sont les bienvenus. Les lits supplémentaires ou les hébergements additionnels dépendent de la capacité de la chambre et des disponibilités.",
        "Russian": "Дети могут проживать в отеле. Дополнительные кровати или размещение зависят от вместимости номера и наличия свободных мест."
    },

    "INT013": {
        "Arabic": "تشمل عملية الحجز اختيار التواريخ، واختيار الغرفة، وتقديم معلومات الضيف، ومراجعة الحجز، ثم تأكيده.",
        "French": "Le processus de réservation comprend la sélection des dates, le choix de la chambre, la fourniture des informations du client, la vérification de la réservation et sa confirmation.",
        "Russian": "Процесс бронирования включает выбор дат, выбор номера, предоставление информации о госте, проверку данных бронирования и подтверждение."
    },

    "INT014": {
        "Arabic": "قد تتضمن معلومات الحجز الاسم الكامل للضيف، وعدد الضيوف، وتاريخ تسجيل الوصول، وتاريخ تسجيل المغادرة، ونوع الغرفة، ومعلومات الاتصال، ومعلومات الدفع عند الحاجة.",
        "French": "Les informations de réservation peuvent inclure le nom complet du client, le nombre de personnes, les dates d'arrivée et de départ, le type de chambre, les coordonnées et les informations de paiement lorsque cela est requis.",
        "Russian": "Информация для бронирования может включать полное имя гостя, количество гостей, даты заезда и выезда, тип номера, контактные данные и платежную информацию, если это требуется."
    },

    "INT015": {
        "Arabic": "يمكن للضيوف التواصل مع خدمة العملاء لطلب تعديل الحجوزات. تخضع التعديلات للتوافر وموافقة الفندق.",
        "French": "Les clients peuvent contacter le service client pour demander des modifications à leur réservation. Les modifications dépendent des disponibilités et de l'approbation de l'hôtel.",
        "Russian": "Гости могут обратиться в службу поддержки, чтобы изменить бронирование. Изменения зависят от наличия свободных номеров и одобрения отеля."
    },

    "INT016": {
        "Arabic": "يتم تأكيد الحجز بعد تقديم معلومات الحجز المطلوبة وإتمام عملية الحجز.",
        "French": "Une réservation est confirmée après la fourniture des informations requises et l'achèvement du processus de réservation.",
        "Russian": "Бронирование подтверждается после предоставления необходимой информации и завершения процесса бронирования."
    },

    "INT017": {
        "Arabic": "يمكن للضيوف التواصل مع خدمة العملاء لطلب المساعدة في إلغاء الحجز، ويجب عليهم تقديم تفاصيل الحجز ذات الصلة.",
        "French": "Les clients peuvent contacter le service client pour demander de l'aide concernant l'annulation et doivent fournir les informations pertinentes de la réservation.",
        "Russian": "Гости могут обратиться в службу поддержки для отмены бронирования и должны предоставить соответствующие данные бронирования."
    },

    "INT018": {
        "Arabic": "تعتمد أهلية إلغاء الحجز على الشروط المرتبطة بالحجز.",
        "French": "L'éligibilité à l'annulation dépend des conditions associées à la réservation.",
        "Russian": "Возможность отмены зависит от условий, связанных с бронированием."
    },

    "INT019": {
        "Arabic": "تعتمد أي رسوم إلغاء مطبقة على شروط الإلغاء المرتبطة بالحجز.",
        "French": "Les éventuels frais d'annulation dépendent des conditions d'annulation associées à la réservation.",
        "Russian": "Размер возможной платы за отмену зависит от условий отмены, связанных с бронированием."
    },

    "INT020": {
        "Arabic": "لا تحدد قاعدة المعرفة الحالية طرق الدفع المقبولة في الفندق. يجب على الضيوف التواصل مع خدمة العملاء لمعرفة طرق الدفع المتاحة حاليًا.",
        "French": "La base de connaissances actuelle ne précise pas les modes de paiement acceptés par l'hôtel. Les clients doivent contacter le service client pour connaître les modes de paiement actuellement disponibles.",
        "Russian": "В текущей базе знаний не указаны точные способы оплаты, принимаемые отелем. Гостям следует обратиться в службу поддержки для получения актуальной информации."
    },

    "INT021": {
        "Arabic": "تعتمد متطلبات الدفع على الحجز المحدد وسياسات الفندق المعمول بها.",
        "French": "Les exigences de paiement dépendent de la réservation sélectionnée et des politiques de l'hôtel applicables.",
        "Russian": "Требования к оплате зависят от выбранного бронирования и действующих правил отеля."
    },

    "INT022": {
        "Arabic": "قد يتم تطبيق رسوم إضافية على بعض خدمات الفندق أو الأضرار التي تلحق بممتلكات الفندق.",
        "French": "Des frais supplémentaires peuvent s'appliquer à certains services de l'hôtel ou aux dommages causés aux biens de l'hôtel.",
        "Russian": "За некоторые услуги отеля или повреждение имущества отеля может взиматься дополнительная плата."
    },

    "INT023": {
        "Arabic": "تعتمد أهلية استرداد المبلغ على الشروط المرتبطة بالحجز.",
        "French": "L'éligibilité au remboursement dépend des conditions associées à la réservation.",
        "Russian": "Возможность возврата средств зависит от условий, связанных с бронированием."
    },

    "INT024": {
        "Arabic": "تتم معالجة المبالغ المستردة المؤهلة وفقًا لشروط الدفع والاسترداد المعمول بها. لا تحدد قاعدة المعرفة الحالية مدة ثابتة لمعالجة الاسترداد.",
        "French": "Les remboursements admissibles sont traités conformément aux conditions de paiement et de remboursement applicables. La base de connaissances actuelle ne précise pas de délai fixe de traitement.",
        "Russian": "Подлежащие возврату средства обрабатываются в соответствии с действующими условиями оплаты и возврата. В текущей базе знаний не указан фиксированный срок обработки возврата."
    },

    "INT025": {
        "Arabic": "يتوفر الإفطار يوميًا من الساعة 7:00 صباحًا حتى 10:30 صباحًا في المطعم الرئيسي.",
        "French": "Le petit-déjeuner est servi tous les jours de 7h00 à 10h30 au restaurant principal.",
        "Russian": "Завтрак подается ежедневно с 7:00 до 10:30 в главном ресторане."
    },

    "INT026": {
        "Arabic": "سعر الإفطار هو 450 جنيهًا مصريًا للشخص الواحد.",
        "French": "Le petit-déjeuner coûte 450 EGP par personne.",
        "Russian": "Стоимость завтрака составляет 450 EGP с человека."
    },

    "INT027": {
        "Arabic": "خدمة الغرف متاحة على مدار 24 ساعة. يمكن للضيوف طلب الطعام والمشروبات مباشرة إلى غرفهم.",
        "French": "Le service d'étage est disponible 24 heures sur 24. Les clients peuvent commander de la nourriture et des boissons directement dans leur chambre.",
        "Russian": "Обслуживание номеров доступно круглосуточно. Гости могут заказывать еду и напитки прямо в номер."
    },

    "INT028": {
        "Arabic": "خدمة النقل من وإلى المطار متاحة عند الطلب وتكلف 800 جنيه مصري للرحلة الواحدة.",
        "French": "Le transfert aéroport est disponible sur demande et coûte 800 EGP par trajet.",
        "Russian": "Трансфер из аэропорта и в аэропорт предоставляется по запросу и стоит 800 EGP за поездку."
    },

    "INT029": {
        "Arabic": "خدمات غسيل الملابس والتنظيف الجاف متاحة يوميًا، وتبلغ تكلفة خدمة غسيل الملابس 200 جنيه مصري لكل كيلوغرام.",
        "French": "Le service de blanchisserie et de nettoyage à sec est disponible tous les jours. Le service de blanchisserie coûte 200 EGP par kilogramme.",
        "Russian": "Услуги прачечной и химчистки доступны ежедневно. Стоимость стирки составляет 200 EGP за килограмм."
    },

    "INT030": {
        "Arabic": "تتوفر علاجات السبا من الساعة 9:00 صباحًا حتى 10:00 مساءً، وتبلغ تكلفة الجلسة 1,200 جنيه مصري.",
        "French": "Les soins du spa sont disponibles de 9h00 à 22h00 et coûtent 1 200 EGP par séance.",
        "Russian": "Спа-процедуры доступны с 9:00 до 22:00 и стоят 1 200 EGP за сеанс."
    },

    "INT031": {
        "Arabic": "صالة الألعاب الرياضية في الفندق متاحة على مدار 24 ساعة لنزلاء الفندق.",
        "French": "La salle de sport de l'hôtel est disponible 24 heures sur 24 pour les clients de l'hôtel.",
        "Russian": "Тренажерный зал отеля доступен круглосуточно для гостей."
    },

    "INT032": {
        "Arabic": "يقدم المطعم الرئيسي الإفطار يوميًا من الساعة 7:00 صباحًا حتى 10:30 صباحًا. ولا تحدد قاعدة المعرفة الحالية خدمات المطعم خارج فترة الإفطار.",
        "French": "Le restaurant principal sert le petit-déjeuner tous les jours de 7h00 à 10h30. La base de connaissances actuelle ne précise pas les services du restaurant en dehors du petit-déjeuner.",
        "Russian": "Главный ресторан ежедневно подает завтрак с 7:00 до 10:30. В текущей базе знаний не указаны услуги ресторана вне времени завтрака."
    },

    "INT033": {
        "Arabic": "تتوفر خدمة الواي فاي المجانية على مدار 24 ساعة في جميع غرف الضيوف والمناطق العامة.",
        "French": "Le Wi-Fi gratuit est disponible 24 heures sur 24 dans toutes les chambres et les espaces publics.",
        "Russian": "Бесплатный Wi-Fi доступен круглосуточно во всех номерах и общественных зонах."
    },

    "INT034": {
        "Arabic": "موقف السيارات متاح لنزلاء الفندق.",
        "French": "Le parking est disponible pour les clients de l'hôtel.",
        "Russian": "Парковка доступна для гостей отеля."
    },

    "INT035": {
        "Arabic": "حمام السباحة متاح لنزلاء الفندق من الساعة 7:00 صباحًا حتى 9:00 مساءً.",
        "French": "La piscine est disponible pour les clients de l'hôtel de 7h00 à 21h00.",
        "Russian": "Бассейн доступен для гостей отеля с 7:00 до 21:00."
    },

    "INT036": {
        "Arabic": "لا يُسمح بالحيوانات الأليفة داخل الفندق، بما في ذلك غرف الضيوف ومرافق الفندق.",
        "French": "Les animaux domestiques ne sont pas autorisés dans l'hôtel, y compris dans les chambres et les installations.",
        "Russian": "Домашние животные не допускаются в отель, включая номера и гостиничные объекты."
    },

    "INT037": {
        "Arabic": "يُمنع التدخين داخل غرف الضيوف والمناطق العامة الداخلية. توجد مناطق مخصصة للتدخين.",
        "French": "Il est interdit de fumer dans les chambres et les espaces publics intérieurs. Des zones fumeurs désignées sont disponibles.",
        "Russian": "Курение запрещено в номерах и внутренних общественных зонах. Для курения предусмотрены специальные места."
    },

    "INT038": {
        "Arabic": "الأطفال مرحب بهم في الفندق. تخضع الأسرّة الإضافية أو أماكن الإقامة الإضافية لسعة الغرفة والتوافر.",
        "French": "Les enfants sont les bienvenus à l'hôtel. Les lits supplémentaires ou les hébergements additionnels dépendent de la capacité de la chambre et des disponibilités.",
        "Russian": "Дети могут проживать в отеле. Дополнительные кровати или размещение зависят от вместимости номера и наличия свободных мест."
    },

    "INT039": {
        "Arabic": "يجب على الضيوف الذين يفقدون أحد أغراضهم التواصل مع مكتب الاستقبال. تتم إدارة الأشياء التي يتم العثور عليها داخل الفندق من خلال قسم المفقودات.",
        "French": "Les clients qui perdent un objet doivent contacter la réception. Les objets trouvés dans l'hôtel sont pris en charge par le service des objets trouvés.",
        "Russian": "Гостям, потерявшим вещь, следует обратиться на стойку регистрации. Найденные в отеле вещи передаются в отдел находок."
    },

    "INT040": {
        "Arabic": "يجب على الضيوف الحفاظ على مستويات ضوضاء معقولة، خاصة خلال ساعات الليل.",
        "French": "Les clients doivent maintenir un niveau sonore raisonnable, en particulier pendant les heures nocturnes.",
        "Russian": "Гости должны соблюдать разумный уровень шума, особенно в ночное время."
    },

    "INT041": {
        "Arabic": "يُتوقع من الضيوف احترام ممتلكات الفندق وموظفيه والضيوف الآخرين. وقد تؤدي الأضرار التي تلحق بممتلكات الفندق إلى رسوم إضافية.",
        "French": "Les clients sont tenus de respecter les biens de l'hôtel, son personnel et les autres clients. Les dommages causés aux biens de l'hôtel peuvent entraîner des frais supplémentaires.",
        "Russian": "Гости должны уважать имущество отеля, персонал и других гостей. Повреждение имущества отеля может привести к дополнительным расходам."
    },

    "INT042": {
        "Arabic": "تتم معالجة معلومات الضيوف وفقًا لإجراءات الخصوصية والأمان الخاصة بالفندق. ولا توفر قاعدة المعرفة الحالية سياسة الخصوصية الكاملة أو فترات الاحتفاظ المحددة بالبيانات.",
        "French": "Les informations des clients sont traitées conformément aux procédures de confidentialité et de sécurité de l'hôtel. La base de connaissances actuelle ne fournit pas la politique de confidentialité complète ni les périodes précises de conservation des données.",
        "Russian": "Информация о гостях обрабатывается в соответствии с процедурами конфиденциальности и безопасности отеля. В текущей базе знаний не указана полная политика конфиденциальности или конкретные сроки хранения данных."
    },

    "INT043": {
        "Arabic": "في حالة الطوارئ، يجب على الضيوف التواصل مع مكتب استقبال الفندق فورًا. يعمل مكتب الاستقبال على مدار 24 ساعة.",
        "French": "En cas d'urgence, les clients doivent contacter immédiatement la réception de l'hôtel. La réception est ouverte 24 heures sur 24.",
        "Russian": "В случае чрезвычайной ситуации гости должны немедленно обратиться на стойку регистрации. Стойка регистрации работает круглосуточно."
    }
}

# %%
# Keep only active intents
localized_answers = {
    intent_id: answers
    for intent_id, answers in localized_answers.items()
    if intent_id in set(intent_df_clean["intent_id"])
}

print("=" * 70)
print("LOCALIZED ANSWERS VALIDATION")
print("=" * 70)

print("Active intents:", len(intent_df_clean))
print("Localized intents:", len(localized_answers))

expected_languages = {"Arabic", "French", "Russian"}

missing = []

for intent_id in intent_df_clean["intent_id"]:

    if intent_id not in localized_answers:
        missing.append((intent_id, "all"))

        continue

    for language in expected_languages:

        if not localized_answers[intent_id].get(language, "").strip():
            missing.append((intent_id, language))

print("Missing translations:", len(missing))

if missing:
    print("⚠️ Missing:")
    for item in missing:
        print(item)
else:
    print("✅ ALL ACTIVE INTENTS HAVE ARABIC, FRENCH AND RUSSIAN ANSWERS")
# Out:
# ...
# LOCALIZED ANSWERS VALIDATION
# ...
# Active intents: 42
# Localized intents: 42
# Missing translations: 0
# ✅ ALL ACTIVE INTENTS HAVE ARABIC, FRENCH AND RUSSIAN ANSWERS

# %%
# ============================================================
# BUILD FINAL MULTILINGUAL GROUND TRUTH
# ============================================================

def get_ground_truth(row):

    intent_id = row["intent_id"]
    language = row["language"]

    # English answer
    if language == "English":
        return ground_truth_catalog[intent_id]

    # Arabic / French / Russian
    return localized_answers[intent_id][language]


generation_plan_df["ground_truth"] = generation_plan_df.apply(
    get_ground_truth,
    axis=1
)

print("=" * 70)
print("FINAL GROUND TRUTH MAPPING")
print("=" * 70)

print("Total rows:", len(generation_plan_df))

print(
    "Missing ground truth:",
    generation_plan_df["ground_truth"].isna().sum()
)

print(
    "Empty ground truth:",
    (
        generation_plan_df["ground_truth"]
        .astype(str)
        .str.strip()
        .eq("")
    ).sum()
)

print("\nGround truth by language:")

print(
    generation_plan_df
    .groupby("language")["ground_truth"]
    .count()
)

print("\nSample:")

print(
    generation_plan_df[
        [
            "faq_id",
            "intent_id",
            "intent_name",
            "language",
            "question_type",
            "ground_truth"
        ]
    ].head(12).to_string(index=False)
)
# Out:
# ...
# FINAL GROUND TRUTH MAPPING
# ...
# Total rows: 1344
# Missing ground truth: 0
# Empty ground truth: 0
#
# Ground truth by language:
# language
# Arabic     336
# English    336
# French     336
# Russian    336
# Name: ground_truth, dtype: int64
#
# Sample:
#  faq_id intent_id    intent_name language question_type                                 ground_truth
# FAQ0001    INT001 hotel_location  English        Direct Nile Pearl Hotel is located in Cairo, Egypt.
# FAQ0002    INT001 hotel_location  English        Direct Nile Pearl Hotel is located in Cairo, Egypt.
# FAQ0003    INT001 hotel_location  English        Direct Nile Pearl Hotel is located in Cairo, Egypt.
# FAQ0004    INT001 hotel_location  English   Paraphrased Nile Pearl Hotel is located in Cairo, Egypt.
# FAQ0005    INT001 hotel_location  English   Paraphrased Nile Pearl Hotel is located in Cairo, Egypt.
# FAQ0006    INT001 hotel_location  English   Paraphrased Nile Pearl Hotel is located in Cairo, Egypt.
# ...

# %%
# ============================================================
# PREPARE FINAL FAQ DATASET
# ============================================================

faq_df = generation_plan_df.copy()

faq_df["question"] = ""
faq_df["answer"] = faq_df["ground_truth"]

faq_df = faq_df[
    [
        "faq_id",
        "intent_id",
        "intent_name",
        "category",
        "language",
        "question_type",
        "difficulty",
        "question",
        "answer",
        "ground_truth",
        "source"
    ]
]

print("=" * 70)
print("FINAL FAQ DATASET STRUCTURE")
print("=" * 70)

print("Rows:", len(faq_df))
print("Columns:", len(faq_df.columns))

print("\nColumns:")
print(faq_df.columns.tolist())

print("\nMissing values:")
print(faq_df.isna().sum())
# Out:
# ...
# FINAL FAQ DATASET STRUCTURE
# ...
# Rows: 1344
# Columns: 11
#
# Columns:
# ['faq_id', 'intent_id', 'intent_name', 'category', 'language', 'question_type', 'difficulty', 'question', 'answer', 'ground_truth', 'source']
#
# Missing values:
# faq_id           0
# intent_id        0
# intent_name      0
# category         0
# language         0
# question_type    0
# difficulty       0
# question         0
# answer           0
# ground_truth     0
# source           0
# dtype: int64

# %%
# ============================================================
# QUESTION GENERATION RULES
# ============================================================

question_rules = {
    "Direct": {
        "count": 3,
        "description": "Ask the intent directly and clearly.",
        "style": "Short, natural, factual question."
    },

    "Paraphrased": {
        "count": 3,
        "description": "Ask the same intent using different wording.",
        "style": "Natural variation without changing the meaning."
    },

    "Scenario": {
        "count": 2,
        "description": "Ask the intent through a realistic hotel guest situation.",
        "style": "Natural customer scenario followed by a question."
    }
}

print("=" * 70)
print("QUESTION GENERATION RULES")
print("=" * 70)

for q_type, rule in question_rules.items():
    print(f"\n{q_type}")
    print("Count:", rule["count"])
    print("Description:", rule["description"])
    print("Style:", rule["style"])
# Out:
# ...
# QUESTION GENERATION RULES
# ...
#
# Direct
# Count: 3
# Description: Ask the intent directly and clearly.
# Style: Short, natural, factual question.
#
# Paraphrased
# Count: 3
# Description: Ask the same intent using different wording.
# Style: Natural variation without changing the meaning.
#
# Scenario
# Count: 2
# Description: Ask the intent through a realistic hotel guest situation.
# Style: Natural customer scenario followed by a question.

# %%
def build_question_prompt(row):
    
    return f"""
You are generating training data for a multilingual hotel AI assistant.

HOTEL:
Nile Pearl Hotel

INTENT:
{row['intent_name']}

CATEGORY:
{row['category']}

LANGUAGE:
{row['language']}

QUESTION TYPE:
{row['question_type']}

GROUND TRUTH:
{row['ground_truth']}

SOURCE:
{row['source']}

TASK:
Generate ONE natural guest question that matches the specified intent.

RULES:
1. The question MUST be written in {row['language']}.
2. The question MUST match the intent exactly.
3. Do not introduce information that is not supported by the ground truth.
4. Do not change prices, times, policies, room capacities, or conditions.
5. Direct questions must be clear and straightforward.
6. Paraphrased questions must use different wording but preserve the exact meaning.
7. Scenario questions must describe a realistic guest situation.
8. Do not answer the question.
9. Do not mention the intent name.
10. Return ONLY the question.

Generate one question now.
"""

# %%
# ============================================================
# IMPROVED QUESTION GENERATION PROMPT
# ============================================================

def build_question_prompt(row, existing_questions=None):

    if existing_questions is None:
        existing_questions = []

    previous_questions = "\n".join(
        f"- {q}" for q in existing_questions
    )

    if not previous_questions:
        previous_questions = "None"

    return f"""
You are generating high-quality training data for a multilingual hotel AI assistant.

HOTEL:
Nile Pearl Hotel

INTENT:
{row['intent_name']}

CATEGORY:
{row['category']}

LANGUAGE:
{row['language']}

QUESTION TYPE:
{row['question_type']}

GROUND TRUTH:
{row['ground_truth']}

SOURCE:
{row['source']}

PREVIOUS QUESTIONS FOR THIS INTENT:
{previous_questions}

TASK:
Generate ONE natural guest question that matches the specified intent.

STRICT RULES:

1. The question MUST be written entirely in {row['language']}.
2. The question MUST match the intent exactly.
3. The question MUST be answerable using the provided ground truth.
4. Do NOT introduce information that is not supported by the ground truth.
5. Do NOT change prices, times, policies, room capacities, or conditions.
6. Do NOT ask about multiple intents in the same question.
7. Do NOT answer the question.
8. Do NOT mention the intent name.
9. Do NOT copy any previous question.
10. The new question must be meaningfully different from previous questions.

QUESTION TYPE RULES:

Direct:
Ask the intent clearly and directly.

Paraphrased:
Ask the same intent using substantially different wording while preserving the exact meaning.

Scenario:
Create a realistic hotel guest situation that naturally leads to the same intent.

QUALITY REQUIREMENTS:

- Natural human wording.
- Concise.
- Relevant to a hotel guest.
- No unnecessary details.
- No invented facts.
- No repetition.

Return ONLY ONE question.
Do not include quotation marks.
Do not include explanations.

Generate the question now.
"""

# %%
# ============================================================
# PILOT TEST - INT001
# ============================================================

test_rows = faq_df[
    faq_df["intent_id"] == "INT001"
].copy()

existing_questions = []

for _, row in test_rows.iterrows():

    prompt = build_question_prompt(
        row,
        existing_questions
    )

    print("=" * 70)
    print("FAQ ID:", row["faq_id"])
    print("Language:", row["language"])
    print("Type:", row["question_type"])
    print("=" * 70)
    print(prompt)

    # بعد ما نستخدم الـLLM لإنتاج السؤال:
    # existing_questions.append(generated_question)
# Out:
# ...
# FAQ ID: FAQ0001
# Language: English
# Type: Direct
# ...
#
# You are generating high-quality training data for a multilingual hotel AI assistant.
#
# HOTEL:
# Nile Pearl Hotel
#
# INTENT:
# hotel_location
#
# CATEGORY:
# Hotel Information
#
# LANGUAGE:
# English
#
# QUESTION TYPE:
# Direct
#
# GROUND TRUTH:
# Nile Pearl Hotel is located in Cairo, Egypt.
#
# SOURCE:
# hotel_information.txt
#
# PREVIOUS QUESTIONS FOR THIS INTENT:
# None
#
# TASK:
# Generate ONE natural guest question that matches the specified intent.
#
# STRICT RULES:
#
# 1. The question MUST be written entirely in English.
# 2. The question MUST match the intent exactly.
# 3. The question MUST be answerable using the provided ground truth.
# 4. Do NOT introduce information that is not supported by the ground truth.
# 5. Do NOT change prices, times, policies, room capacities, or conditions.
# 6. Do NOT ask about multiple intents in the same question.
# 7. Do NOT answer the question.
# 8. Do NOT mention the intent name.
# ...

# %%
# !pip install openai -q
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# httpcore 0.9.1 requires h11<0.10,>=0.8, but you have h11 0.16.0 which is incompatible.
# httpx 0.13.3 requires idna==2.*, but you have idna 3.18 which is incompatible.
#
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from openai import OpenAI
import getpass

api_key = getpass.getpass("Enter your OpenAI API key: ")

client = OpenAI(api_key=api_key)

print("✅ OpenAI client initialized successfully.")
# Out:
# ✅ OpenAI client initialized successfully.

# %%
import os

# ============================================================
# HOTEL AI - FULL PROJECT STRUCTURE
# ============================================================

PROJECT_ROOT = "."

print("=" * 80)
print("HOTEL AI - CURRENT PROJECT STRUCTURE")
print("=" * 80)

def print_tree(path, prefix=""):
    
    try:
        items = sorted(
            os.listdir(path),
            key=lambda x: (not os.path.isdir(os.path.join(path, x)), x.lower())
        )
    except PermissionError:
        print(prefix + "⚠️ Permission denied")
        return

    for index, item in enumerate(items):

        full_path = os.path.join(path, item)
        is_last = index == len(items) - 1

        connector = "└── " if is_last else "├── "
        print(prefix + connector + item)

        if os.path.isdir(full_path):
            extension = "    " if is_last else "│   "
            print_tree(full_path, prefix + extension)


print_tree(PROJECT_ROOT)

print("\n" + "=" * 80)
print("IMPORTANT FILE CHECK")
print("=" * 80)

important_paths = [
    "02_Hotel_Knowledge",
    "03_Structured_Data",
    "data",
    "database",
    "scripts",
    "README.md",
    "generate_hotel_faq.ipynb"
]

for path in important_paths:

    if os.path.exists(path):
        if os.path.isdir(path):
            print(f"✅ {path}/")
        else:
            size = os.path.getsize(path)
            print(f"✅ {path} ({size:,} bytes)")
    else:
        print(f"❌ {path} - MISSING")
# Out:
# ...
# HOTEL AI - CURRENT PROJECT STRUCTURE
# ...
# ├── 02_Hotel_Knowledge
# │   ├── Booking
# │   │   ├── booking_confirmation.txt
# │   │   ├── booking_modification.txt
# │   │   ├── booking_policy.txt
# │   │   └── booking_process.txt
# │   ├── Cancellation
# │   │   ├── cancellation_policy.txt
# │   │   └── cancellation_process.txt
# │   ├── Hotel_Information
# │   │   ├── contact_information.txt
# │   │   ├── hotel_facilities.txt
# │   │   └── hotel_information.txt
# │   ├── Payment
# │   │   ├── payment_methods.txt
# │   │   ├── payment_policy.txt
# │   │   └── refund_policy.txt
# │   ├── Policies
# │   │   ├── check_in_check_out.txt
# │   │   ├── children_policy.txt
# │   │   ├── emergency_policy.txt
# │   │   ├── guest_conduct.txt
# │   │   ├── identification_policy.txt
# │   │   ├── lost_and_found.txt
# │   │   ├── noise_policy.txt
# │   │   ├── pet_policy.txt
# │   │   ├── privacy_policy.txt
# │   │   └── smoking_policy.txt
# │   ├── Rooms
# │   │   ├── room_amenities.txt
# ...
